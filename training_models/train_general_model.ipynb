# %% [markdown]
# - For some unseen locations, a general models is trained on the entire dataset made by combining extracted counts from all the camera ids. This model is used for predicting turning movement counts for unseen location for which expected counts are not generated.
#
# - For training the models, the same approach is used here as explained in `train.ipynb`.

# %% [markdown]
# ## Importing Dependencies

# %%
import os
import numpy as np
import pandas as pd
from pathlib import Path
from typing import Tuple

from sklearn.preprocessing import StandardScaler
from joblib import dump, load
from sklearn.model_selection import train_test_split

from cuml.linear_model import LinearRegression, Lasso, ElasticNet
from cuml.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor, AdaBoostRegressor
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import r2_score
from joblib import parallel_backend
from ray.util.joblib import register_ray
register_ray()
import ray
from cuml.common.device_selection import set_global_device_type

np.random.seed(42)

# %% [markdown]
# ### Connecting to a ray cluster

# %%
set_global_device_type("GPU")
ray.init("auto")
# Out:
# 2024-08-24 18:25:07,568	INFO worker.py:1596 -- Connecting to existing Ray cluster at address: 10.19.3.211:6379...
# 2024-08-24 18:25:07,573	INFO worker.py:1772 -- Connected to Ray cluster. View the dashboard at 127.0.0.1:8265
# RayContext(dashboard_url='127.0.0.1:8265', python_version='3.10.12', ray_version='2.34.0', ray_commit='fc87217e031b4e551cbb3d3ffc75f8c0fb57886a')

# %%
dataset_dir = Path(r"/home/user1/codes/bangaluru_mobility_codes/submission/future_counts/data")
save_dir = Path(r"/home/user1/codes/bangaluru_mobility_codes/submission/future_counts/model_training/results")

# %%
acc_models = {"RandomForest","LinearRegression","Lasso","ElasticNet","XGBRegressor","CatBoostingRegressor"}
target_column = "count"

# %%
# Specify parameters and distributions to sample from for hyper-parameter tuning
params={
        "RandomForest":{
            'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
            'max_features':['sqrt','log2'],
            'n_estimators': [8,16,32,64,128,256,512,1024],
            'bootstrap': [False, True]
        },
        "GradientBoosting":{
            'loss':['squared_error', 'huber', 'absolute_error', 'quantile'],
            'learning_rate':[.1,.01,.05,.001],
            'subsample':[0.6,0.7,0.75,0.8,0.85,0.9],
            'criterion':['squared_error', 'friedman_mse'],
            'max_features':['sqrt','log2'],
            'n_estimators': [8,16,32,64,128,256]
        },
        "LinearRegression":{
            'algorithm': ['svd', 'eig', 'qr', 'svd-qr', 'svd-jacobi']
        },
        "XGBRegressor":{
            'learning_rate': np.linspace(0.001,0.2,8),
            'n_estimators': np.arange(8,512,50),
            'gamma': np.linspace(0,5,10),
            'reg_alpha': np.logspace(-3,1,10),
            'reg_lambda': np.logspace(-3,1,10)
        },
        "CatBoostingRegressor":{
            'depth': [4,6,8,10],
            'l2_leaf_reg': np.logspace(-2,1,10),
            'learning_rate': np.linspace(0.001,0.2,8),
            'iterations': np.arange(10,500,50)
        },
        "AdaBoostRegressor":{
            'learning_rate': np.linspace(0.001,0.2,8),
            'loss':['linear','square','exponential'],
            'n_estimators': np.arange(8,512,50),
        },
        "Lasso":{
            'alpha':  (np.logspace(-8, 8, 100)),
        },
        "ElasticNet": {
            'alpha': np.logspace(-4,2,30),
            'l1_ratio': np.linspace(0,1,30),
            'fit_intercept': [True, False]
        }
 }

# %%
def load_dateset(path: str) -> pd.DataFrame:
    """
    Load and preprocess a dataset from a CSV file.

    Removes any rows containing NaN values, and converts certain columns to more memory-efficient data types.
    The columns are then reordered for easier access.

    Parameters:
    path (str): The file path to the CSV file containing the dataset.

    Returns:
    pd.DataFrame
    """
    df = pd.read_csv(path)
    df = df.dropna()
    df["class"] = df["class"].astype(np.int8)
    df["zone_in"] = df["zone_in"].astype(np.int8)
    df["zone_out"] = df["zone_out"].astype(np.int8)
    df["count"] = df["count"].astype(np.int16)
    df["last_15_min_count"] = df["last_15_min_count"].astype(np.int16)
    df["last_30_min_count"] = df["last_30_min_count"].astype(np.int16)
    df = df.iloc[:,[0,1,2,4,5,3]]

    return df

# %%
def load_models() -> dict:
    """
    Initializes and returns a dictionary of machine learning models.

    Returns:
        dict: a dictonary of machine learning models with key as model name and value as model object 
    """
    models = {
        "ElasticNet": ElasticNet(copy_X=False),
        "XGBRegressor":XGBRegressor(),
        "LinearRegression":LinearRegression(copy_X=False),
        "RandomForest":RandomForestRegressor(),
        "GradientBoosting":GradientBoostingRegressor(),
        "CatBoostingRegressor":CatBoostRegressor(verbose=False),
        "AdaBoostRegressor":AdaBoostRegressor(),
        "Lasso": Lasso(copy_X=False),
    }

    return models

# %%
def split_dataset(df: pd.DataFrame, cam_id: str) -> Tuple[np.ndarray, np.ndarray, np.ndarray, np.ndarray]:
    """
    Splits the dataset into training and testing sets, scales the input features, and saves the scaler into a pickled file. 

    Parameters:
    -----------
    df (pd.DataFrame): The DataFrame containing the dataset to be split and scaled.
    
    cam_id (str): A unique identifier for the camera or dataset being processed. This ID is used to save the scaler with a specific name.

    Returns:
    --------
    Tuple[np.ndarray, np.ndarray, np.ndarray, np.ndarray]
    """
    scaler = StandardScaler()
    
    split = 0.20
    train_set, test_set = train_test_split(df, test_size=split, shuffle=True, random_state=42)
    input_feature_train_df = train_set.drop([target_column], axis=1)
    target_feature_train_df = pd.DataFrame(train_set[target_column])

    input_feature_test_df = test_set.drop([target_column], axis=1)
    target_feature_test_df = pd.DataFrame(test_set[target_column])
    
    input_feature_train_arr = scaler.fit_transform(input_feature_train_df)
    input_feature_test_arr = scaler.transform(input_feature_test_df)

    train_arr = np.c_[
        input_feature_train_arr, np.array(target_feature_train_df)
    ]

    test_arr = np.c_[
        input_feature_test_arr, np.array(target_feature_test_df)
    ]

    dump(scaler, save_dir / "scalers" / f"{cam_id}.pkl")
    print(f"SC saved to {save_dir / 'scalers' / f'{cam_id}.pkl'}")

    X_train, y_train = train_arr[:, :-1], train_arr[:, -1]
    X_test, y_test = test_arr[:, :-1], test_arr[:, -1]

    return X_train, y_train, X_test, y_test

# %%
# Make a dataset for all the camera ids
dfs = []
for file in os.listdir(dataset_dir):
    if file.endswith(".csv"):
        df = load_dateset(dataset_dir / file)
        dfs.append(df)
        
df = pd.concat(dfs, axis=0, ignore_index=True)

# %% [markdown]
# ### Train models

# %%
# Training a general model
cam_id = "general"
models_report = {
    cam_id: dict()
}

# Train and test split with scaled features
X_train, y_train, X_test, y_test = split_dataset(df, cam_id)

# Initalize the models
models = load_models()

os.makedirs(save_dir / "models" / cam_id, exist_ok=True)

for model_name, model in models.items():
    print(f"Now evaluating: {model_name}\n\n")

    para = params[model_name]

    # Hyperparameter tuning for GPU supported models
    if model_name in acc_models:
        gs = RandomizedSearchCV(model, para, cv=5, n_iter=25, verbose=4, n_jobs=10)
        with parallel_backend('ray', ray_remote_args=dict(num_gpus=0.01)):
            gs.fit(X_train, y_train)
    else:
        # Hyperparameter tuning for non-GPU supported models
        gs = RandomizedSearchCV(model, para, cv=5, n_iter=30, verbose=4, n_jobs=-1)
        with parallel_backend('ray'):
            gs.fit(X_train, y_train)

        
    model.set_params(**gs.best_params_)
    # Fit the model with best parameters
    model.fit(X_train, y_train)

    # Save a pickled copy of the model
    dump(model, save_dir / "models" / cam_id / f"{model_name}.pkl")
    print(f"{model_name} saved to {save_dir / 'models' / cam_id}") 

    # Evaluate the model
    y_test_pred = model.predict(X_test)
    test_model_score = r2_score(y_test, y_test_pred)
    
    y_test_org = y_test.reshape(-1,1)
    y_test_pred = y_test_pred.reshape(-1,1)
    y_test_pred = np.array(y_test_pred, dtype=int)

    test_mae = np.mean(np.absolute(y_test_pred - y_test_org))
    test_rmse = np.sqrt(np.mean((y_test_pred - y_test_org)**2))

    parameters = gs.best_params_

    models_report[cam_id][model_name] = (test_model_score, test_mae, test_rmse, parameters)
    

print("Best model score and parameters:\n")
print(sorted(models_report[cam_id].items(), key= lambda kv: (-kv[1][0], kv[1][1], kv[1][2]))[0])

print("\n\n\n")
# Out:
# 2024-08-24 18:25:30,399	WARNING pool.py:589 -- The 'context' argument is not supported using ray. Please refer to the documentation for how to control ray initialization.
# SC saved to /home/user1/codes/bangaluru_mobility_codes/submission/future_counts/model_training/results/scalers/general.pkl
# [I] [18:25:30.287608] Unused keyword parameter: copy_X during cuML estimator initialization
# [I] [18:25:30.327929] Unused keyword parameter: copy_X during cuML estimator initialization
# Now evaluating: ElasticNet
#
#
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# ElasticNet saved to /home/user1/codes/bangaluru_mobility_codes/submission/future_counts/model_training/results/models/general
# Now evaluating: XGBRegressor
#
#
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# XGBRegressor saved to /home/user1/codes/bangaluru_mobility_codes/submission/future_counts/model_training/results/models/general
# Now evaluating: LinearRegression
# (PoolActor pid=2537627) [CV 1/5] END alpha=0.12689610031679222, fit_intercept=False, l1_ratio=0.4482758620689655;, score=0.879 total time=   0.3s
# (PoolActor pid=2537627) [CV 1/5] END alpha=0.0002592943797404667, fit_intercept=False, l1_ratio=0.41379310344827586;, score=0.885 total time=   0.0s
# (PoolActor pid=2537626) [CV 5/5] END alpha=0.07880462815669911, fit_intercept=True, l1_ratio=1.0;, score=0.955 total time=   0.0s
# (PoolActor pid=2540208) [CV 1/5] END gamma=2.7777777777777777, learning_rate=0.2, n_estimators=308, reg_alpha=0.00774263682681127, reg_lambda=0.4641588833612777;, score=0.959 total time=   0.5s
# (PoolActor pid=2537629) [CV 2/5] END alpha=0.00452035365636024, fit_intercept=False, l1_ratio=0.9655172413793103;, score=0.882 total time=   0.0s [repeated 58x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (PoolActor pid=2537628) [CV 3/5] END alpha=0.007278953843983146, fit_intercept=True, l1_ratio=0.7241379310344828;, score=0.949 total time=   0.0s [repeated 64x across cluster]
# (PoolActor pid=2540208) [CV 1/5] END gamma=1.1111111111111112, learning_rate=0.2, n_estimators=458, reg_alpha=3.5938136638046254, reg_lambda=10.0;, score=0.958 total time=   0.9s [repeated 85x across cluster]
# (PoolActor pid=2543462) [CV 3/5] END .....................algorithm=svd;, score=0.949 total time=   0.1s
# (PoolActor pid=2543462) [CV 3/5] END ......................algorithm=qr;, score=0.949 total time=   0.0s
# (PoolActor pid=2543462) [CV 3/5] END ..............algorithm=svd-jacobi;, score=0.949 total time=   0.0s
# (PoolActor pid=2540215) [CV 3/5] END gamma=0.5555555555555556, learning_rate=0.11471428571428573, n_estimators=208, reg_alpha=0.00774263682681127, reg_lambda=10.0;, score=0.956 total time=   0.5s [repeated 39x across cluster]
# (PoolActor pid=2543468) [CV 2/5] END .....................algorithm=eig;, score=0.953 total time=   0.1s
# (PoolActor pid=2543468) [CV 2/5] END ..................algorithm=svd-qr;, score=0.953 total time=   0.0s
# /home/user1/codes/bangaluru_mobility_codes/base/lib/python3.10/site-packages/sklearn/model_selection/_search.py:320: UserWarning: The total space of parameters 5 is smaller than n_iter=25. Running 5 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# LinearRegression saved to /home/user1/codes/bangaluru_mobility_codes/submission/future_counts/model_training/results/models/general
# Now evaluating: RandomForest
#
#
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# (PoolActor pid=2544637) /home/user1/codes/bangaluru_mobility_codes/base/lib/python3.10/site-packages/cuml/internals/api_decorators.py:188: UserWarning: To use pickling first train using float32 data to fit the estimator
# (PoolActor pid=2544637)   ret = func(*args, **kwargs)
# (PoolActor pid=2544639) [CV 2/5] END bootstrap=False, criterion=friedman_mse, max_features=log2, n_estimators=32;, score=0.933 total time=   2.8s
# (PoolActor pid=2543466) [CV 5/5] END .....................algorithm=svd;, score=0.955 total time=   0.1s [repeated 4x across cluster]
# (PoolActor pid=2543465) [CV 4/5] END ......................algorithm=qr;, score=0.954 total time=   0.0s [repeated 4x across cluster]
# (PoolActor pid=2543465) [CV 4/5] END ..............algorithm=svd-jacobi;, score=0.954 total time=   0.0s [repeated 4x across cluster]
# (PoolActor pid=2543470) [CV 4/5] END .....................algorithm=eig;, score=0.954 total time=   0.2s [repeated 4x across cluster]
# (PoolActor pid=2543470) [CV 4/5] END ..................algorithm=svd-qr;, score=0.954 total time=   0.0s [repeated 4x across cluster]
# (PoolActor pid=2544637) [CV 5/5] END bootstrap=True, criterion=absolute_error, max_features=log2, n_estimators=1024;, score=0.941 total time= 1.5min
# (PoolActor pid=2544638) [CV 1/5] END bootstrap=False, criterion=friedman_mse, max_features=log2, n_estimators=32;, score=0.942 total time=   3.0s [repeated 4x across cluster]
# (PoolActor pid=2544639) [CV 2/5] END bootstrap=False, criterion=squared_error, max_features=log2, n_estimators=1024;, score=0.935 total time= 1.5min
# (PoolActor pid=2544637) [CV 5/5] END bootstrap=False, criterion=absolute_error, max_features=sqrt, n_estimators=256;, score=0.941 total time=  22.0s
# (PoolActor pid=2544643) [CV 1/5] END bootstrap=True, criterion=absolute_error, max_features=log2, n_estimators=1024;, score=0.943 total time= 1.5min [repeated 4x across cluster]
# (PoolActor pid=2544638) [CV 1/5] END bootstrap=False, criterion=squared_error, max_features=log2, n_estimators=1024;, score=0.943 total time= 1.5min [repeated 4x across cluster]
# (PoolActor pid=2544639) [CV 2/5] END bootstrap=False, criterion=absolute_error, max_features=log2, n_estimators=256;, score=0.935 total time=  21.5s
# (PoolActor pid=2544639) [CV 2/5] END bootstrap=False, criterion=squared_error, max_features=sqrt, n_estimators=8;, score=0.932 total time=   0.5s
# (PoolActor pid=2544637) [CV 5/5] END bootstrap=True, criterion=squared_error, max_features=sqrt, n_estimators=128;, score=0.941 total time=   9.4s
# (PoolActor pid=2544644) [CV 2/5] END bootstrap=False, criterion=absolute_error, max_features=sqrt, n_estimators=256;, score=0.935 total time=  22.2s [repeated 4x across cluster]
# (PoolActor pid=2544640) [CV 3/5] END bootstrap=False, criterion=squared_error, max_features=log2, n_estimators=16;, score=0.934 total time=   1.2s [repeated 5x across cluster]
# (PoolActor pid=2544640) [CV 3/5] END bootstrap=False, criterion=absolute_error, max_features=log2, n_estimators=256;, score=0.934 total time=  21.9s [repeated 4x across cluster]
# (PoolActor pid=2544640) [CV 3/5] END bootstrap=False, criterion=squared_error, max_features=sqrt, n_estimators=8;, score=0.934 total time=   0.7s [repeated 4x across cluster]
# (PoolActor pid=2544644) [CV 2/5] END bootstrap=True, criterion=squared_error, max_features=sqrt, n_estimators=128;, score=0.935 total time=   9.7s [repeated 4x across cluster]
# (PoolActor pid=2544639) [CV 2/5] END bootstrap=False, criterion=absolute_error, max_features=log2, n_estimators=512;, score=0.935 total time=  44.3s
# (PoolActor pid=2544638) [CV 1/5] END bootstrap=False, criterion=absolute_error, max_features=log2, n_estimators=512;, score=0.943 total time=  44.4s
# (PoolActor pid=2544637) [CV 5/5] END bootstrap=True, criterion=absolute_error, max_features=sqrt, n_estimators=1024;, score=0.941 total time= 1.4min
# (PoolActor pid=2544642) [CV 5/5] END bootstrap=False, criterion=absolute_error, max_features=log2, n_estimators=512;, score=0.941 total time=  44.4s [repeated 3x across cluster]
# (PoolActor pid=2544637) [CV 5/5] END bootstrap=False, criterion=friedman_mse, max_features=log2, n_estimators=128;, score=0.941 total time=  10.7s
# (PoolActor pid=2544644) [CV 2/5] END bootstrap=True, criterion=absolute_error, max_features=sqrt, n_estimators=1024;, score=0.935 total time= 1.4min [repeated 4x across cluster]
# (PoolActor pid=2544637) [CV 5/5] END bootstrap=False, criterion=absolute_error, max_features=log2, n_estimators=32;, score=0.940 total time=   2.6s
# (PoolActor pid=2544637) [CV 5/5] END bootstrap=True, criterion=squared_error, max_features=sqrt, n_estimators=16;, score=0.939 total time=   1.3s
# (PoolActor pid=2544644) [CV 2/5] END bootstrap=False, criterion=friedman_mse, max_features=log2, n_estimators=128;, score=0.935 total time=  11.1s [repeated 4x across cluster]
# (PoolActor pid=2544637) [CV 5/5] END bootstrap=False, criterion=squared_error, max_features=log2, n_estimators=32;, score=0.940 total time=   2.7s
# (PoolActor pid=2544643) [CV 1/5] END bootstrap=False, criterion=absolute_error, max_features=log2, n_estimators=32;, score=0.942 total time=   2.8s [repeated 4x across cluster]
# (PoolActor pid=2544645) [CV 3/5] END bootstrap=True, criterion=poisson, max_features=log2, n_estimators=64;, score=0.935 total time=   5.5s
# (PoolActor pid=2544643) [CV 1/5] END bootstrap=True, criterion=squared_error, max_features=sqrt, n_estimators=16;, score=0.942 total time=   1.4s [repeated 4x across cluster]
# (PoolActor pid=2544643) [CV 1/5] END bootstrap=False, criterion=squared_error, max_features=log2, n_estimators=32;, score=0.942 total time=   2.6s [repeated 4x across cluster]
# (PoolActor pid=2544639) [CV 2/5] END bootstrap=False, criterion=absolute_error, max_features=log2, n_estimators=1024;, score=0.935 total time= 1.3min
# (PoolActor pid=2544643) [CV 1/5] END bootstrap=True, criterion=poisson, max_features=log2, n_estimators=64;, score=0.943 total time=   5.7s [repeated 4x across cluster]
# (PoolActor pid=2544639) [CV 2/5] END bootstrap=True, criterion=squared_error, max_features=sqrt, n_estimators=8;, score=0.934 total time=   0.3s
# (PoolActor pid=2544639) [CV 2/5] END bootstrap=False, criterion=friedman_mse, max_features=sqrt, n_estimators=8;, score=0.932 total time=   0.7s
# (PoolActor pid=2544639) [CV 2/5] END bootstrap=True, criterion=poisson, max_features=sqrt, n_estimators=16;, score=0.932 total time=   1.4s
# (PoolActor pid=2544640) [CV 3/5] END bootstrap=False, criterion=absolute_error, max_features=log2, n_estimators=1024;, score=0.934 total time= 1.3min [repeated 4x across cluster]
# (PoolActor pid=2544639) [CV 2/5] END bootstrap=True, criterion=squared_error, max_features=sqrt, n_estimators=64;, score=0.935 total time=   5.7s [repeated 5x across cluster]
# (PoolActor pid=2544640) [CV 3/5] END bootstrap=False, criterion=friedman_mse, max_features=sqrt, n_estimators=8;, score=0.934 total time=   0.7s [repeated 4x across cluster]
# (PoolActor pid=2544640) [CV 3/5] END bootstrap=True, criterion=poisson, max_features=sqrt, n_estimators=16;, score=0.934 total time=   1.4s [repeated 4x across cluster]
# (PoolActor pid=2544639) [CV 2/5] END bootstrap=True, criterion=squared_error, max_features=log2, n_estimators=8;, score=0.934 total time=   0.6s
# (PoolActor pid=2544639) [CV 2/5] END bootstrap=True, criterion=friedman_mse, max_features=log2, n_estimators=8;, score=0.934 total time=   0.6s
# (PoolActor pid=2544643) [CV 1/5] END bootstrap=False, criterion=poisson, max_features=log2, n_estimators=256;, score=0.943 total time=  16.9s
# (PoolActor pid=2544640) [CV 3/5] END bootstrap=True, criterion=squared_error, max_features=sqrt, n_estimators=64;, score=0.935 total time=   5.7s [repeated 4x across cluster]
# (PoolActor pid=2544640) [CV 3/5] END bootstrap=True, criterion=squared_error, max_features=log2, n_estimators=8;, score=0.935 total time=   0.6s [repeated 4x across cluster]
# (PoolActor pid=2544642) [CV 5/5] END bootstrap=True, criterion=friedman_mse, max_features=log2, n_estimators=8;, score=0.940 total time=   0.7s [repeated 4x across cluster]
# (PoolActor pid=2544637) [CV 5/5] END bootstrap=False, criterion=poisson, max_features=log2, n_estimators=256;, score=0.941 total time=  17.2s [repeated 4x across cluster]
# (PoolActor pid=2544643) [CV 1/5] END bootstrap=True, criterion=squared_error, max_features=log2, n_estimators=256;, score=0.943 total time=  11.0s
# (PoolActor pid=2544644) [CV 2/5] END bootstrap=True, criterion=squared_error, max_features=log2, n_estimators=256;, score=0.935 total time=  12.0s
# (PoolActor pid=2544643) [CV 1/5] END bootstrap=False, criterion=poisson, max_features=log2, n_estimators=1024;, score=0.943 total time=  41.0s
# (PoolActor pid=2544646) [CV 4/5] END bootstrap=True, criterion=squared_error, max_features=log2, n_estimators=256;, score=0.944 total time=  12.3s [repeated 3x across cluster]
# (PoolActor pid=2544644) [CV 2/5] END bootstrap=False, criterion=poisson, max_features=log2, n_estimators=1024;, score=0.935 total time=  43.5s
# /home/user1/codes/bangaluru_mobility_codes/base/lib/python3.10/site-packages/cuml/internals/api_decorators.py:188: UserWarning: To use pickling first train using float32 data to fit the estimator
#   ret = func(*args, **kwargs)
# (PoolActor pid=2544637) Exception ignored in: <cyfunction RandomForestRegressor.__del__ at 0x7d46399ab850>
# (PoolActor pid=2544637) Traceback (most recent call last):
# (PoolActor pid=2544637)   File "randomforestregressor.pyx", line 321, in cuml.ensemble.randomforestregressor.RandomForestRegressor.__del__
# (PoolActor pid=2544637)   File "randomforestregressor.pyx", line 337, in cuml.ensemble.randomforestregressor.RandomForestRegressor._reset_forest_data
# (PoolActor pid=2544637) AttributeError: 'NoneType' object has no attribute 'free_treelite_model'
# (PoolActor pid=2544640) /home/user1/codes/bangaluru_mobility_codes/base/lib/python3.10/site-packages/cuml/internals/api_decorators.py:188: UserWarning: To use pickling first train using float32 data to fit the estimator [repeated 9x across cluster]
# (PoolActor pid=2544640)   ret = func(*args, **kwargs) [repeated 9x across cluster]
# RandomForest saved to /home/user1/codes/bangaluru_mobility_codes/submission/future_counts/model_training/results/models/general
# Now evaluating: GradientBoosting
#
#
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# GradientBoosting saved to /home/user1/codes/bangaluru_mobility_codes/submission/future_counts/model_training/results/models/general
# Now evaluating: CatBoostingRegressor
#
#
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# CatBoostingRegressor saved to /home/user1/codes/bangaluru_mobility_codes/submission/future_counts/model_training/results/models/general
# Now evaluating: AdaBoostRegressor
#
#
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# AdaBoostRegressor saved to /home/user1/codes/bangaluru_mobility_codes/submission/future_counts/model_training/results/models/general
# Now evaluating: Lasso
#
#
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# Lasso saved to /home/user1/codes/bangaluru_mobility_codes/submission/future_counts/model_training/results/models/general
# Best model score and parameters:
#
# ('CatBoostingRegressor', (0.9612666175929678, 2.5843723274969617, 9.827441730866624, {'learning_rate': 0.029428571428571432, 'l2_leaf_reg': 2.154434690031882, 'iterations': 360, 'depth': 8}))
# (PoolActor pid=2549103) [CV 1/5] END criterion=squared_error, learning_rate=0.001, loss=absolute_error, max_features=log2, n_estimators=8, subsample=0.8;, score=-0.076 total time=   0.3s
# (PoolActor pid=2544645) [CV 3/5] END bootstrap=False, criterion=poisson, max_features=log2, n_estimators=1024;, score=0.934 total time=  43.4s [repeated 3x across cluster]
# (PoolActor pid=2548418) [CV 1/5] END criterion=squared_error, learning_rate=0.1, loss=absolute_error, max_features=sqrt, n_estimators=8, subsample=0.6;, score=-0.076 total time=   0.5s
# (PoolActor pid=2548435) [CV 5/5] END criterion=friedman_mse, learning_rate=0.001, loss=absolute_error, max_features=log2, n_estimators=32, subsample=0.6;, score=-0.076 total time=   0.9s
# (PoolActor pid=2548426) [CV 1/5] END criterion=squared_error, learning_rate=0.01, loss=squared_error, max_features=log2, n_estimators=8, subsample=0.8;, score=0.124 total time=   0.3s
# (PoolActor pid=2548436) [CV 5/5] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=sqrt, n_estimators=16, subsample=0.6;, score=-0.063 total time=   1.4s
# (PoolActor pid=2549419) [CV 2/5] END criterion=friedman_mse, learning_rate=0.05, loss=squared_error, max_features=sqrt, n_estimators=8, subsample=0.9;, score=0.496 total time=   1.0s
# (PoolActor pid=2549605) [CV 3/5] END criterion=squared_error, learning_rate=0.1, loss=huber, max_features=log2, n_estimators=8, subsample=0.7;, score=0.395 total time=   1.3s
# (PoolActor pid=2548433) [CV 3/5] END criterion=friedman_mse, learning_rate=0.05, loss=quantile, max_features=log2, n_estimators=32, subsample=0.85;, score=0.897 total time=   3.3s
# (PoolActor pid=2548411) [CV 1/5] END criterion=friedman_mse, learning_rate=0.1, loss=huber, max_features=sqrt, n_estimators=32, subsample=0.85;, score=0.896 total time=   4.8s
# (PoolActor pid=2548416) [CV 1/5] END criterion=squared_error, learning_rate=0.05, loss=absolute_error, max_features=log2, n_estimators=64, subsample=0.75;, score=-0.076 total time=   3.8s [repeated 6x across cluster]
# (PoolActor pid=2548420) [CV 3/5] END criterion=squared_error, learning_rate=0.1, loss=absolute_error, max_features=sqrt, n_estimators=8, subsample=0.6;, score=-0.078 total time=   0.7s [repeated 2x across cluster]
# (PoolActor pid=2548411) [CV 2/5] END criterion=friedman_mse, learning_rate=0.1, loss=huber, max_features=log2, n_estimators=16, subsample=0.75;, score=0.597 total time=   1.2s
# (PoolActor pid=2548434) [CV 2/5] END criterion=friedman_mse, learning_rate=0.001, loss=absolute_error, max_features=log2, n_estimators=32, subsample=0.6;, score=-0.075 total time=   1.0s
# (PoolActor pid=2549393) [CV 5/5] END criterion=squared_error, learning_rate=0.01, loss=squared_error, max_features=log2, n_estimators=8, subsample=0.8;, score=0.134 total time=   0.6s
# (PoolActor pid=2549556) [CV 5/5] END criterion=squared_error, learning_rate=0.01, loss=squared_error, max_features=sqrt, n_estimators=128, subsample=0.8;, score=0.861 total time=   6.0s
# (PoolActor pid=1658249, ip=192.168.124.155) [CV 3/5] END criterion=friedman_mse, learning_rate=0.001, loss=absolute_error, max_features=log2, n_estimators=32, subsample=0.6;, score=-0.078 total time=   1.0s
# (PoolActor pid=2548425) [CV 1/5] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=sqrt, n_estimators=128, subsample=0.6;, score=0.165 total time=   7.1s
# (PoolActor pid=2548409) [CV 3/5] END criterion=squared_error, learning_rate=0.001, loss=huber, max_features=log2, n_estimators=64, subsample=0.9;, score=-0.031 total time=   8.3s [repeated 7x across cluster]
# (PoolActor pid=2548432) [CV 4/5] END criterion=friedman_mse, learning_rate=0.05, loss=quantile, max_features=log2, n_estimators=32, subsample=0.85;, score=0.913 total time=   3.4s
# (PoolActor pid=2548415) [CV 5/5] END criterion=squared_error, learning_rate=0.01, loss=huber, max_features=sqrt, n_estimators=32, subsample=0.85;, score=0.113 total time=   2.0s
# (PoolActor pid=2548429) [CV 5/5] END criterion=squared_error, learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=8, subsample=0.6;, score=0.745 total time=   0.2s
# (PoolActor pid=2548412) [CV 4/5] END criterion=friedman_mse, learning_rate=0.1, loss=huber, max_features=sqrt, n_estimators=32, subsample=0.85;, score=0.910 total time=   5.1s
# (PoolActor pid=2548430) [CV 2/5] END criterion=squared_error, learning_rate=0.01, loss=absolute_error, max_features=log2, n_estimators=256, subsample=0.85;, score=-0.075 total time=   9.5s [repeated 3x across cluster]
# (PoolActor pid=2548421) [CV 2/5] END criterion=friedman_mse, learning_rate=0.1, loss=huber, max_features=log2, n_estimators=64, subsample=0.8;, score=0.952 total time=   8.1s [repeated 4x across cluster]
# (PoolActor pid=2549487) [CV 1/5] END criterion=friedman_mse, learning_rate=0.01, loss=huber, max_features=sqrt, n_estimators=128, subsample=0.9;, score=0.502 total time=  10.7s
# (PoolActor pid=2548438) [CV 5/5] END criterion=squared_error, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=256, subsample=0.75;, score=0.363 total time=  12.9s
# (PoolActor pid=2548424) [CV 5/5] END criterion=squared_error, learning_rate=0.001, loss=squared_error, max_features=sqrt, n_estimators=256, subsample=0.75;, score=0.355 total time=  10.9s [repeated 3x across cluster]
# (PoolActor pid=2548440) [CV 5/5] END criterion=friedman_mse, learning_rate=0.001, loss=absolute_error, max_features=log2, n_estimators=256, subsample=0.9;, score=-0.076 total time=  10.4s [repeated 2x across cluster]
# (PoolActor pid=2549255) [CV 4/5] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=sqrt, n_estimators=128, subsample=0.6;, score=0.161 total time=   7.1s
# (PoolActor pid=565195, ip=10.19.0.100) [CV 2/5] END criterion=squared_error, learning_rate=0.001, loss=huber, max_features=log2, n_estimators=64, subsample=0.9;, score=-0.032 total time=   4.6s
# (PoolActor pid=2548431) [CV 4/5] END criterion=squared_error, learning_rate=0.01, loss=quantile, max_features=sqrt, n_estimators=256, subsample=0.8;, score=0.915 total time=  14.7s
# (PoolActor pid=2548409) [CV 4/5] END criterion=squared_error, learning_rate=0.01, loss=huber, max_features=sqrt, n_estimators=32, subsample=0.85;, score=0.107 total time=   1.9s [repeated 2x across cluster]
# (PoolActor pid=2548767) [CV 1/5] END criterion=squared_error, learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=256, subsample=0.85;, score=0.960 total time=  10.6s [repeated 3x across cluster]
# (PoolActor pid=1658252, ip=192.168.124.155) [CV 1/5] END criterion=friedman_mse, learning_rate=0.05, loss=quantile, max_features=log2, n_estimators=32, subsample=0.85;, score=0.914 total time=   2.0s
# (PoolActor pid=1658219, ip=192.168.124.155) [CV 1/5] END criterion=squared_error, learning_rate=0.01, loss=absolute_error, max_features=log2, n_estimators=256, subsample=0.85;, score=-0.076 total time=   8.1s
# (PoolActor pid=2549269) [CV 4/5] END criterion=friedman_mse, learning_rate=0.001, loss=huber, max_features=log2, n_estimators=256, subsample=0.6;, score=0.077 total time=  14.1s
# (PoolActor pid=565204, ip=10.19.0.100) [CV 3/5] END criterion=friedman_mse, learning_rate=0.1, loss=huber, max_features=sqrt, n_estimators=32, subsample=0.85;, score=0.901 total time=   2.4s [repeated 2x across cluster]
# (PoolActor pid=2548437) [CV 1/5] END criterion=squared_error, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=256, subsample=0.75;, score=0.367 total time=  13.4s
# (PoolActor pid=1658256, ip=192.168.124.155) [CV 3/5] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=sqrt, n_estimators=16, subsample=0.6;, score=-0.072 total time=   0.9s
# (PoolActor pid=1658227, ip=192.168.124.155) [CV 1/5] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=sqrt, n_estimators=16, subsample=0.6;, score=-0.056 total time=   0.9s
# (PoolActor pid=1658257, ip=192.168.124.155) [CV 4/5] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=sqrt, n_estimators=16, subsample=0.6;, score=-0.063 total time=   0.9s
# (PoolActor pid=565214, ip=10.19.0.100) [CV 5/5] END criterion=squared_error, learning_rate=0.01, loss=absolute_error, max_features=log2, n_estimators=256, subsample=0.85;, score=-0.076 total time=   7.8s
# (PoolActor pid=1658250, ip=192.168.124.155) [CV 3/5] END criterion=friedman_mse, learning_rate=0.1, loss=quantile, max_features=log2, n_estimators=16, subsample=0.6;, score=0.902 total time=   0.9s
# (PoolActor pid=1658222, ip=192.168.124.155) [CV 1/5] END criterion=squared_error, learning_rate=0.01, loss=quantile, max_features=sqrt, n_estimators=256, subsample=0.8;, score=0.925 total time=  14.8s
# (PoolActor pid=1658231, ip=192.168.124.155) [CV 5/5] END criterion=squared_error, learning_rate=0.1, loss=absolute_error, max_features=sqrt, n_estimators=8, subsample=0.6;, score=-0.076 total time=   0.3s
# (PoolActor pid=1658230, ip=192.168.124.155) [CV 4/5] END criterion=squared_error, learning_rate=0.05, loss=absolute_error, max_features=log2, n_estimators=64, subsample=0.75;, score=-0.078 total time=   2.1s
# (PoolActor pid=565219, ip=10.19.0.100) [CV 5/5] END criterion=friedman_mse, learning_rate=0.05, loss=quantile, max_features=log2, n_estimators=32, subsample=0.85;, score=0.911 total time=   2.0s
# (PoolActor pid=565220, ip=10.19.0.100) [CV 4/5] END criterion=friedman_mse, learning_rate=0.001, loss=absolute_error, max_features=log2, n_estimators=32, subsample=0.6;, score=-0.078 total time=   1.0s
# (PoolActor pid=1658259, ip=192.168.124.155) [CV 4/5] END criterion=friedman_mse, learning_rate=0.1, loss=quantile, max_features=log2, n_estimators=16, subsample=0.6;, score=0.907 total time=   1.0s
# (PoolActor pid=565196, ip=10.19.0.100) [CV 2/5] END criterion=squared_error, learning_rate=0.01, loss=quantile, max_features=sqrt, n_estimators=256, subsample=0.8;, score=0.913 total time=  14.9s
# (PoolActor pid=1658236, ip=192.168.124.155) [CV 2/5] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=sqrt, n_estimators=128, subsample=0.6;, score=0.161 total time=   6.9s
# (PoolActor pid=1658229, ip=192.168.124.155) [CV 1/5] END criterion=friedman_mse, learning_rate=0.001, loss=absolute_error, max_features=log2, n_estimators=256, subsample=0.9;, score=-0.076 total time=   8.5s
# (PoolActor pid=1658260, ip=192.168.124.155) [CV 2/5] END criterion=friedman_mse, learning_rate=0.001, loss=absolute_error, max_features=log2, n_estimators=256, subsample=0.9;, score=-0.075 total time=   8.6s
# (PoolActor pid=565202, ip=10.19.0.100) [CV 3/5] END criterion=squared_error, learning_rate=0.05, loss=absolute_error, max_features=log2, n_estimators=64, subsample=0.75;, score=-0.078 total time=   2.0s
# (PoolActor pid=565217, ip=10.19.0.100) [CV 5/5] END criterion=friedman_mse, learning_rate=0.1, loss=quantile, max_features=log2, n_estimators=16, subsample=0.6;, score=0.895 total time=   0.9s
# (PoolActor pid=565218, ip=10.19.0.100) [CV 3/5] END criterion=squared_error, learning_rate=0.01, loss=quantile, max_features=sqrt, n_estimators=256, subsample=0.8;, score=0.912 total time=  15.2s
# (PoolActor pid=1658251, ip=192.168.124.155) [CV 1/5] END criterion=friedman_mse, learning_rate=0.1, loss=huber, max_features=log2, n_estimators=64, subsample=0.8;, score=0.957 total time=   5.0s
# (PoolActor pid=1658253, ip=192.168.124.155) [CV 1/5] END criterion=friedman_mse, learning_rate=0.001, loss=absolute_error, max_features=log2, n_estimators=32, subsample=0.6;, score=-0.076 total time=   1.1s
# (PoolActor pid=1658263, ip=192.168.124.155) [CV 4/5] END criterion=friedman_mse, learning_rate=0.1, loss=huber, max_features=log2, n_estimators=64, subsample=0.8;, score=0.956 total time=   5.1s
# (PoolActor pid=565222, ip=10.19.0.100) [CV 2/5] END criterion=friedman_mse, learning_rate=0.1, loss=quantile, max_features=log2, n_estimators=16, subsample=0.6;, score=0.890 total time=   0.9s
# (PoolActor pid=565289, ip=10.19.0.100) [CV 4/5] END criterion=friedman_mse, learning_rate=0.05, loss=squared_error, max_features=sqrt, n_estimators=8, subsample=0.9;, score=0.514 total time=   0.4s
# (PoolActor pid=1658254, ip=192.168.124.155) [CV 5/5] END criterion=squared_error, learning_rate=0.001, loss=absolute_error, max_features=log2, n_estimators=8, subsample=0.8;, score=-0.076 total time=   0.3s
# (PoolActor pid=565216, ip=10.19.0.100) [CV 2/5] END criterion=squared_error, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=256, subsample=0.75;, score=0.359 total time=  14.7s
# (PoolActor pid=565207, ip=10.19.0.100) [CV 5/5] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=sqrt, n_estimators=128, subsample=0.6;, score=0.161 total time=   6.7s
# (PoolActor pid=1658264, ip=192.168.124.155) [CV 5/5] END criterion=friedman_mse, learning_rate=0.1, loss=huber, max_features=log2, n_estimators=64, subsample=0.8;, score=0.955 total time=   5.2s
# (PoolActor pid=565213, ip=10.19.0.100) [CV 4/5] END criterion=squared_error, learning_rate=0.1, loss=huber, max_features=log2, n_estimators=8, subsample=0.7;, score=0.371 total time=   0.6s
# (PoolActor pid=565200, ip=10.19.0.100) [CV 4/5] END criterion=squared_error, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=256, subsample=0.75;, score=0.373 total time=  14.7s
# (PoolActor pid=1658267, ip=192.168.124.155) [CV 5/5] END criterion=friedman_mse, learning_rate=0.1, loss=absolute_error, max_features=log2, n_estimators=8, subsample=0.7;, score=-0.076 total time=   0.3s
# (PoolActor pid=565203, ip=10.19.0.100) [CV 4/5] END criterion=squared_error, learning_rate=0.1, loss=absolute_error, max_features=sqrt, n_estimators=8, subsample=0.6;, score=-0.078 total time=   0.3s
# (PoolActor pid=1658262, ip=192.168.124.155) [CV 2/5] END criterion=squared_error, learning_rate=0.1, loss=huber, max_features=log2, n_estimators=8, subsample=0.7;, score=0.338 total time=   0.7s
# (PoolActor pid=565194, ip=10.19.0.100) [CV 2/5] END criterion=friedman_mse, learning_rate=0.1, loss=huber, max_features=sqrt, n_estimators=32, subsample=0.85;, score=0.909 total time=   2.5s
# (PoolActor pid=1658258, ip=192.168.124.155) [CV 3/5] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=sqrt, n_estimators=128, subsample=0.6;, score=0.161 total time=   7.0s
# (PoolActor pid=565225, ip=10.19.0.100) [CV 4/5] END criterion=friedman_mse, learning_rate=0.001, loss=absolute_error, max_features=log2, n_estimators=256, subsample=0.9;, score=-0.078 total time=   7.9s
# (PoolActor pid=1658237, ip=192.168.124.155) [CV 4/5] END criterion=squared_error, learning_rate=0.01, loss=squared_error, max_features=log2, n_estimators=8, subsample=0.8;, score=0.135 total time=   0.4s
# (PoolActor pid=1658268, ip=192.168.124.155) [CV 1/5] END criterion=squared_error, learning_rate=0.01, loss=squared_error, max_features=sqrt, n_estimators=128, subsample=0.8;, score=0.856 total time=   5.6s
# (PoolActor pid=1658238, ip=192.168.124.155) [CV 3/5] END criterion=friedman_mse, learning_rate=0.05, loss=squared_error, max_features=sqrt, n_estimators=8, subsample=0.9;, score=0.497 total time=   0.4s
# (PoolActor pid=1658255, ip=192.168.124.155) [CV 3/5] END criterion=friedman_mse, learning_rate=0.001, loss=huber, max_features=log2, n_estimators=256, subsample=0.6;, score=0.083 total time=  17.7s
# (PoolActor pid=565223, ip=10.19.0.100) [CV 3/5] END criterion=squared_error, learning_rate=0.001, loss=absolute_error, max_features=log2, n_estimators=8, subsample=0.8;, score=-0.078 total time=   0.3s
# (PoolActor pid=565199, ip=10.19.0.100) [CV 2/5] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=sqrt, n_estimators=16, subsample=0.6;, score=-0.053 total time=   0.8s
# (PoolActor pid=1658265, ip=192.168.124.155) [CV 3/5] END criterion=squared_error, learning_rate=0.01, loss=squared_error, max_features=log2, n_estimators=8, subsample=0.8;, score=0.123 total time=   0.4s
# (PoolActor pid=565215, ip=10.19.0.100) [CV 2/5] END criterion=friedman_mse, learning_rate=0.05, loss=quantile, max_features=log2, n_estimators=32, subsample=0.85;, score=0.897 total time=   2.1s
# (PoolActor pid=1658235, ip=192.168.124.155) [CV 2/5] END criterion=squared_error, learning_rate=0.001, loss=squared_error, max_features=sqrt, n_estimators=256, subsample=0.75;, score=0.346 total time=  10.6s
# (PoolActor pid=1658240, ip=192.168.124.155) [CV 1/5] END criterion=friedman_mse, learning_rate=0.1, loss=absolute_error, max_features=log2, n_estimators=8, subsample=0.7;, score=-0.076 total time=   0.3s
# (PoolActor pid=1658269, ip=192.168.124.155) [CV 4/5] END criterion=squared_error, learning_rate=0.01, loss=huber, max_features=log2, n_estimators=8, subsample=0.9;, score=-0.019 total time=   0.7s
# (PoolActor pid=1658239, ip=192.168.124.155) [CV 5/5] END criterion=friedman_mse, learning_rate=0.01, loss=huber, max_features=sqrt, n_estimators=128, subsample=0.9;, score=0.494 total time=  10.0s
# (PoolActor pid=1658242, ip=192.168.124.155) [CV 4/5] END criterion=friedman_mse, learning_rate=0.1, loss=absolute_error, max_features=log2, n_estimators=8, subsample=0.7;, score=-0.078 total time=   0.3s
# (PoolActor pid=1658241, ip=192.168.124.155) [CV 2/5] END criterion=friedman_mse, learning_rate=0.1, loss=absolute_error, max_features=log2, n_estimators=8, subsample=0.7;, score=-0.075 total time=   0.3s
# (PoolActor pid=565224, ip=10.19.0.100) [CV 3/5] END criterion=squared_error, learning_rate=0.001, loss=squared_error, max_features=sqrt, n_estimators=256, subsample=0.75;, score=0.347 total time=  11.0s
# (PoolActor pid=1658266, ip=192.168.124.155) [CV 2/5] END criterion=friedman_mse, learning_rate=0.01, loss=huber, max_features=sqrt, n_estimators=128, subsample=0.9;, score=0.495 total time=  10.0s
# (PoolActor pid=565233, ip=10.19.0.100) [CV 1/5] END criterion=friedman_mse, learning_rate=0.001, loss=huber, max_features=log2, n_estimators=256, subsample=0.6;, score=0.076 total time=  17.4s
# (PoolActor pid=565211, ip=10.19.0.100) [CV 3/5] END criterion=friedman_mse, learning_rate=0.001, loss=squared_error, max_features=sqrt, n_estimators=128, subsample=0.6;, score=0.193 total time=   5.4s
# (PoolActor pid=565206, ip=10.19.0.100) [CV 5/5] END criterion=squared_error, learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=256, subsample=0.85;, score=0.960 total time=  11.9s
# (PoolActor pid=565201, ip=10.19.0.100) [CV 1/5] END criterion=friedman_mse, learning_rate=0.1, loss=quantile, max_features=log2, n_estimators=16, subsample=0.6;, score=0.886 total time=   0.9s
# (PoolActor pid=565244, ip=10.19.0.100) [CV 5/5] END criterion=friedman_mse, learning_rate=0.001, loss=huber, max_features=log2, n_estimators=256, subsample=0.6;, score=0.076 total time=  18.6s
# (PoolActor pid=565236, ip=10.19.0.100) [CV 2/5] END criterion=friedman_mse, learning_rate=0.001, loss=huber, max_features=log2, n_estimators=256, subsample=0.6;, score=0.078 total time=  18.5s
# (PoolActor pid=565239, ip=10.19.0.100) [CV 2/5] END criterion=squared_error, learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=256, subsample=0.85;, score=0.957 total time=  12.9s
# (PoolActor pid=1658261, ip=192.168.124.155) [CV 2/5] END criterion=friedman_mse, learning_rate=0.001, loss=squared_error, max_features=sqrt, n_estimators=128, subsample=0.6;, score=0.192 total time=   4.7s
# (PoolActor pid=565208, ip=10.19.0.100) [CV 2/5] END criterion=squared_error, learning_rate=0.01, loss=squared_error, max_features=log2, n_estimators=8, subsample=0.8;, score=0.127 total time=   0.4s
# (PoolActor pid=565231, ip=10.19.0.100) [CV 3/5] END criterion=squared_error, learning_rate=0.1, loss=absolute_error, max_features=log2, n_estimators=8, subsample=0.9;, score=-0.078 total time=   0.3s
# (PoolActor pid=1658243, ip=192.168.124.155) [CV 4/5] END criterion=friedman_mse, learning_rate=0.001, loss=squared_error, max_features=sqrt, n_estimators=128, subsample=0.6;, score=0.198 total time=   4.9s [repeated 4x across cluster]
# (PoolActor pid=565235, ip=10.19.0.100) [CV 4/5] END criterion=squared_error, learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=256, subsample=0.85;, score=0.960 total time=  13.2s
# (PoolActor pid=1658246, ip=192.168.124.155) [CV 1/5] END criterion=squared_error, learning_rate=0.01, loss=huber, max_features=log2, n_estimators=8, subsample=0.9;, score=-0.022 total time=   0.6s
# (PoolActor pid=565198, ip=10.19.0.100) [CV 5/5] END criterion=squared_error, learning_rate=0.01, loss=quantile, max_features=sqrt, n_estimators=256, subsample=0.8;, score=0.920 total time=  16.6s
# (PoolActor pid=565194, ip=10.19.0.100) [CV 3/5] END criterion=friedman_mse, learning_rate=0.1, loss=huber, max_features=log2, n_estimators=16, subsample=0.75;, score=0.618 total time=   1.1s
# (PoolActor pid=565195, ip=10.19.0.100) [CV 3/5] END criterion=squared_error, learning_rate=0.01, loss=huber, max_features=sqrt, n_estimators=32, subsample=0.85;, score=0.119 total time=   2.3s
# (PoolActor pid=1658245, ip=192.168.124.155) [CV 3/5] END criterion=squared_error, learning_rate=0.01, loss=squared_error, max_features=sqrt, n_estimators=128, subsample=0.8;, score=0.851 total time=   5.2s
# (PoolActor pid=565205, ip=10.19.0.100) [CV 4/5] END criterion=squared_error, learning_rate=0.001, loss=absolute_error, max_features=log2, n_estimators=8, subsample=0.8;, score=-0.078 total time=   0.3s
# (PoolActor pid=565210, ip=10.19.0.100) [CV 1/5] END criterion=friedman_mse, learning_rate=0.001, loss=squared_error, max_features=sqrt, n_estimators=128, subsample=0.6;, score=0.197 total time=   5.0s
# (PoolActor pid=1658219, ip=192.168.124.155) [CV 2/5] END criterion=squared_error, learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=8, subsample=0.6;, score=0.711 total time=   0.3s
# (PoolActor pid=1658221, ip=192.168.124.155) [CV 1/5] END criterion=squared_error, learning_rate=0.01, loss=huber, max_features=sqrt, n_estimators=32, subsample=0.85;, score=0.113 total time=   2.4s
# (PoolActor pid=565229, ip=10.19.0.100) [CV 2/5] END criterion=squared_error, learning_rate=0.01, loss=squared_error, max_features=sqrt, n_estimators=128, subsample=0.8;, score=0.849 total time=   5.2s
# (PoolActor pid=565227, ip=10.19.0.100) [CV 4/5] END criterion=friedman_mse, learning_rate=0.01, loss=huber, max_features=sqrt, n_estimators=128, subsample=0.9;, score=0.503 total time=  10.3s
# (PoolActor pid=565228, ip=10.19.0.100) [CV 3/5] END criterion=friedman_mse, learning_rate=0.1, loss=absolute_error, max_features=log2, n_estimators=8, subsample=0.7;, score=-0.078 total time=   0.3s
# (PoolActor pid=1658248, ip=192.168.124.155) [CV 5/5] END criterion=squared_error, learning_rate=0.01, loss=huber, max_features=log2, n_estimators=8, subsample=0.9;, score=-0.024 total time=   0.6s
# (PoolActor pid=565295, ip=10.19.0.100) [CV 2/5] END criterion=squared_error, learning_rate=0.1, loss=absolute_error, max_features=log2, n_estimators=8, subsample=0.9;, score=-0.075 total time=   0.3s
# (PoolActor pid=565221, ip=10.19.0.100) [CV 3/5] END criterion=squared_error, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=256, subsample=0.75;, score=0.365 total time=  14.7s
# (PoolActor pid=565234, ip=10.19.0.100) [CV 3/5] END criterion=squared_error, learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=256, subsample=0.85;, score=0.956 total time=  11.2s
# (PoolActor pid=565230, ip=10.19.0.100) [CV 1/5] END criterion=squared_error, learning_rate=0.1, loss=huber, max_features=log2, n_estimators=8, subsample=0.7;, score=0.331 total time=   0.6s
# (PoolActor pid=565212, ip=10.19.0.100) [CV 4/5] END criterion=squared_error, learning_rate=0.01, loss=squared_error, max_features=sqrt, n_estimators=128, subsample=0.8;, score=0.860 total time=   5.6s
# (PoolActor pid=565204, ip=10.19.0.100) [CV 4/5] END criterion=friedman_mse, learning_rate=0.1, loss=huber, max_features=log2, n_estimators=16, subsample=0.75;, score=0.652 total time=   1.1s
# (PoolActor pid=565232, ip=10.19.0.100) [CV 5/5] END criterion=squared_error, learning_rate=0.1, loss=absolute_error, max_features=log2, n_estimators=8, subsample=0.9;, score=-0.076 total time=   0.3s
# (PoolActor pid=565197, ip=10.19.0.100) [CV 5/5] END criterion=friedman_mse, learning_rate=0.1, loss=huber, max_features=sqrt, n_estimators=32, subsample=0.85;, score=0.906 total time=   2.4s
# (PoolActor pid=565197, ip=10.19.0.100) [CV 1/5] END criterion=squared_error, learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=8, subsample=0.6;, score=0.743 total time=   0.3s
# (PoolActor pid=2554707) [CV 5/5] END depth=8, iterations=110, l2_leaf_reg=1.0, learning_rate=0.057857142857142864;, score=0.961 total time=   1.4s
# (PoolActor pid=2554701) [CV 5/5] END depth=10, iterations=460, l2_leaf_reg=0.021544346900318832, learning_rate=0.001;, score=0.571 total time=  10.2s [repeated 15x across cluster]
# (PoolActor pid=2554704) [CV 2/5] END depth=10, iterations=460, l2_leaf_reg=0.046415888336127774, learning_rate=0.029428571428571432;, score=0.957 total time=  11.8s [repeated 14x across cluster]
# (PoolActor pid=2554705) [CV 3/5] END depth=10, iterations=360, l2_leaf_reg=2.154434690031882, learning_rate=0.11471428571428573;, score=0.956 total time=   9.1s [repeated 6x across cluster]
# (PoolActor pid=2554738) [CV 4/5] END depth=8, iterations=410, l2_leaf_reg=0.09999999999999999, learning_rate=0.057857142857142864;, score=0.961 total time=   5.3s [repeated 15x across cluster]
# (PoolActor pid=2554705) [CV 3/5] END depth=6, iterations=410, l2_leaf_reg=0.21544346900318834, learning_rate=0.029428571428571432;, score=0.957 total time=   3.9s [repeated 15x across cluster]
# (PoolActor pid=2554709) [CV 2/5] END depth=8, iterations=60, l2_leaf_reg=0.021544346900318832, learning_rate=0.029428571428571432;, score=0.924 total time=   0.8s [repeated 14x across cluster]
# (PoolActor pid=2554706) [CV 4/5] END depth=10, iterations=160, l2_leaf_reg=1.0, learning_rate=0.14314285714285716;, score=0.961 total time=   4.0s [repeated 7x across cluster]
# (PoolActor pid=2554737) [CV 3/5] END depth=8, iterations=110, l2_leaf_reg=1.0, learning_rate=0.2;, score=0.956 total time=   1.6s [repeated 15x across cluster]
# (PoolActor pid=2554703) [CV 1/5] END depth=6, iterations=360, l2_leaf_reg=10.0, learning_rate=0.001;, score=0.470 total time=   3.9s [repeated 12x across cluster]
# (PoolActor pid=2565763) [CV 2/5] END learning_rate=0.11471428571428573, loss=linear, n_estimators=8;, score=0.945 total time=   1.1s
# (PoolActor pid=2554738) [CV 4/5] END depth=10, iterations=410, l2_leaf_reg=0.021544346900318832, learning_rate=0.001;, score=0.534 total time=   8.4s [repeated 11x across cluster]
# (PoolActor pid=2566376) [CV 1/5] END learning_rate=0.2, loss=square, n_estimators=458;, score=0.930 total time=   5.8s
# (PoolActor pid=2565726) [CV 5/5] END learning_rate=0.14314285714285716, loss=linear, n_estimators=358;, score=0.942 total time=  11.3s [repeated 4x across cluster]
# (PoolActor pid=2565732) [CV 4/5] END learning_rate=0.2, loss=square, n_estimators=258;, score=0.894 total time=  11.9s
# (PoolActor pid=2565726) [CV 1/5] END learning_rate=0.2, loss=exponential, n_estimators=8;, score=0.953 total time=   1.5s
# (PoolActor pid=569364, ip=10.19.0.100) [CV 3/5] END learning_rate=0.14314285714285716, loss=linear, n_estimators=358;, score=0.930 total time=  11.9s [repeated 4x across cluster]
# (PoolActor pid=2565932) [CV 2/5] END learning_rate=0.11471428571428573, loss=square, n_estimators=158;, score=0.910 total time=  14.7s [repeated 3x across cluster]
# (PoolActor pid=2565983) [CV 5/5] END learning_rate=0.2, loss=exponential, n_estimators=8;, score=0.948 total time=   0.9s
# (PoolActor pid=2565724) [CV 4/5] END learning_rate=0.2, loss=exponential, n_estimators=8;, score=0.946 total time=   0.8s
# (PoolActor pid=2565724) [CV 3/5] END learning_rate=0.11471428571428573, loss=linear, n_estimators=358;, score=0.929 total time=  20.2s
# (PoolActor pid=2565789) [CV 2/5] END learning_rate=0.14314285714285716, loss=square, n_estimators=208;, score=0.842 total time=  22.2s [repeated 4x across cluster]
# (PoolActor pid=2566293) [CV 4/5] END learning_rate=0.0862857142857143, loss=linear, n_estimators=358;, score=0.945 total time=  21.8s
# (PoolActor pid=2565815) [CV 4/5] END learning_rate=0.14314285714285716, loss=square, n_estimators=208;, score=0.896 total time=  22.5s
# (PoolActor pid=2567131) [CV 2/5] END learning_rate=0.0862857142857143, loss=linear, n_estimators=358;, score=0.933 total time=  28.4s [repeated 2x across cluster]
# (PoolActor pid=2566209) [CV 4/5] END learning_rate=0.001, loss=square, n_estimators=308;, score=0.939 total time=  31.3s
# (PoolActor pid=2565727) [CV 5/5] END learning_rate=0.057857142857142864, loss=exponential, n_estimators=358;, score=0.945 total time=  35.5s
# (PoolActor pid=2566210) [CV 2/5] END learning_rate=0.0862857142857143, loss=square, n_estimators=458;, score=0.842 total time=  36.7s [repeated 5x across cluster]
# (PoolActor pid=2565901) [CV 4/5] END learning_rate=0.029428571428571432, loss=exponential, n_estimators=408;, score=0.948 total time=  40.7s [repeated 3x across cluster]
# (PoolActor pid=569347, ip=10.19.0.100) [CV 1/5] END learning_rate=0.029428571428571432, loss=square, n_estimators=358;, score=0.933 total time=  39.9s
# (PoolActor pid=2565957) [CV 3/5] END learning_rate=0.029428571428571432, loss=square, n_estimators=508;, score=0.907 total time=  42.9s
# (PoolActor pid=2566044) [CV 1/5] END learning_rate=0.001, loss=exponential, n_estimators=408;, score=0.947 total time=  47.4s [repeated 6x across cluster]
# (PoolActor pid=1672033, ip=192.168.124.155) [CV 3/5] END learning_rate=0.1715714285714286, loss=linear, n_estimators=458;, score=0.934 total time=   8.5s
# (PoolActor pid=1672014, ip=192.168.124.155) [CV 3/5] END learning_rate=0.11471428571428573, loss=square, n_estimators=8;, score=0.933 total time=   1.0s
# (PoolActor pid=2565723) [CV 3/5] END learning_rate=0.029428571428571432, loss=exponential, n_estimators=258;, score=0.940 total time=  15.7s [repeated 4x across cluster]
# (PoolActor pid=1672012, ip=192.168.124.155) [CV 5/5] END learning_rate=0.11471428571428573, loss=linear, n_estimators=358;, score=0.943 total time=  10.4s [repeated 2x across cluster]
# (PoolActor pid=1672048, ip=192.168.124.155) [CV 2/5] END learning_rate=0.057857142857142864, loss=square, n_estimators=58;, score=0.938 total time=   7.0s
# (PoolActor pid=569356, ip=10.19.0.100) [CV 1/5] END learning_rate=0.2, loss=square, n_estimators=258;, score=0.926 total time=   8.7s
# (PoolActor pid=569357, ip=10.19.0.100) [CV 4/5] END learning_rate=0.11471428571428573, loss=linear, n_estimators=8;, score=0.943 total time=   0.9s
# (PoolActor pid=1672026, ip=192.168.124.155) [CV 5/5] END learning_rate=0.2, loss=linear, n_estimators=108;, score=0.941 total time=   6.4s
# (PoolActor pid=1672013, ip=192.168.124.155) [CV 1/5] END learning_rate=0.1715714285714286, loss=linear, n_estimators=458;, score=0.739 total time=  35.7s
# (PoolActor pid=1672019, ip=192.168.124.155) [CV 1/5] END learning_rate=0.14314285714285716, loss=square, n_estimators=208;, score=0.832 total time=  22.6s
# (PoolActor pid=1672020, ip=192.168.124.155) [CV 3/5] END learning_rate=0.14314285714285716, loss=square, n_estimators=208;, score=0.760 total time=  20.3s [repeated 3x across cluster]
# (PoolActor pid=1672027, ip=192.168.124.155) [CV 5/5] END learning_rate=0.0862857142857143, loss=linear, n_estimators=358;, score=0.942 total time=  14.4s
# (PoolActor pid=1672045, ip=192.168.124.155) [CV 5/5] END learning_rate=0.11471428571428573, loss=square, n_estimators=158;, score=0.937 total time=  16.4s
# (PoolActor pid=569387, ip=10.19.0.100) [CV 1/5] END learning_rate=0.2, loss=exponential, n_estimators=508;, score=-2.397 total time=  49.6s
# (PoolActor pid=1672029, ip=192.168.124.155) [CV 4/5] END learning_rate=0.14314285714285716, loss=linear, n_estimators=358;, score=0.946 total time=  12.3s
# (PoolActor pid=569358, ip=10.19.0.100) [CV 1/5] END learning_rate=0.0862857142857143, loss=square, n_estimators=458;, score=0.922 total time=  21.7s
# (PoolActor pid=569383, ip=10.19.0.100) [CV 1/5] END learning_rate=0.2, loss=linear, n_estimators=108;, score=0.940 total time=   7.5s
# (PoolActor pid=569397, ip=10.19.0.100) [CV 3/5] END learning_rate=0.2, loss=exponential, n_estimators=508;, score=-1.923 total time=  49.0s
# (PoolActor pid=1672047, ip=192.168.124.155) [CV 3/5] END learning_rate=0.0862857142857143, loss=square, n_estimators=458;, score=0.512 total time=  50.5s
# (PoolActor pid=569891, ip=10.19.0.100) [CV 2/5] END learning_rate=0.2, loss=linear, n_estimators=108;, score=0.933 total time=  11.3s
# (PoolActor pid=1672017, ip=192.168.124.155) [CV 4/5] END learning_rate=0.001, loss=exponential, n_estimators=408;, score=0.940 total time=  56.1s
# (PoolActor pid=1672016, ip=192.168.124.155) [CV 5/5] END learning_rate=0.057857142857142864, loss=exponential, n_estimators=508;, score=0.940 total time= 1.0min
# (PoolActor pid=1672039, ip=192.168.124.155) [CV 4/5] END learning_rate=0.0862857142857143, loss=linear, n_estimators=408;, score=0.945 total time=  22.3s
# (PoolActor pid=1672042, ip=192.168.124.155) [CV 5/5] END learning_rate=0.057857142857142864, loss=square, n_estimators=58;, score=0.942 total time=   7.9s
# (PoolActor pid=1672035, ip=192.168.124.155) [CV 1/5] END learning_rate=0.057857142857142864, loss=exponential, n_estimators=508;, score=0.886 total time= 1.1min
# (PoolActor pid=1672025, ip=192.168.124.155) [CV 3/5] END learning_rate=0.2, loss=linear, n_estimators=108;, score=0.931 total time=   9.1s
# (PoolActor pid=1672044, ip=192.168.124.155) [CV 5/5] END learning_rate=0.029428571428571432, loss=exponential, n_estimators=408;, score=0.944 total time=  47.2s
# (PoolActor pid=570169, ip=10.19.0.100) [CV 4/5] END learning_rate=0.11471428571428573, loss=square, n_estimators=158;, score=0.906 total time=  20.0s [repeated 2x across cluster]
# (PoolActor pid=570126, ip=10.19.0.100) [CV 1/5] END learning_rate=0.0862857142857143, loss=linear, n_estimators=358;, score=0.941 total time=  26.9s
# (PoolActor pid=1672046, ip=192.168.124.155) [CV 1/5] END learning_rate=0.001, loss=square, n_estimators=308;, score=0.946 total time=  37.7s
# (PoolActor pid=569384, ip=10.19.0.100) [CV 2/5] END learning_rate=0.029428571428571432, loss=linear, n_estimators=208;, score=0.940 total time=  24.9s [repeated 3x across cluster]
# (PoolActor pid=1672031, ip=192.168.124.155) [CV 3/5] END learning_rate=0.2, loss=exponential, n_estimators=8;, score=0.942 total time=   1.1s
# (PoolActor pid=569822, ip=10.19.0.100) [CV 5/5] END learning_rate=0.2, loss=square, n_estimators=458;, score=0.767 total time=  43.4s
# (PoolActor pid=570260, ip=10.19.0.100) [CV 5/5] END learning_rate=0.029428571428571432, loss=linear, n_estimators=208;, score=0.942 total time=  28.5s [repeated 3x across cluster]
# (PoolActor pid=1672050, ip=192.168.124.155) [CV 4/5] END learning_rate=0.2, loss=linear, n_estimators=108;, score=0.944 total time=   8.7s [repeated 2x across cluster]
# (PoolActor pid=569346, ip=10.19.0.100) [CV 1/5] END learning_rate=0.029428571428571432, loss=exponential, n_estimators=258;, score=0.946 total time=  32.5s
# (PoolActor pid=1672043, ip=192.168.124.155) [CV 1/5] END learning_rate=0.14314285714285716, loss=square, n_estimators=108;, score=0.928 total time=  10.7s
# (PoolActor pid=1672034, ip=192.168.124.155) [CV 4/5] END learning_rate=0.001, loss=linear, n_estimators=358;, score=0.941 total time=  44.6s [repeated 2x across cluster]
# (PoolActor pid=569364, ip=10.19.0.100) [CV 4/5] END learning_rate=0.1715714285714286, loss=exponential, n_estimators=308;, score=0.331 total time=  34.4s
# (PoolActor pid=569362, ip=10.19.0.100) [CV 4/5] END learning_rate=0.057857142857142864, loss=square, n_estimators=58;, score=0.943 total time=   8.6s
# (PoolActor pid=1672018, ip=192.168.124.155) [CV 4/5] END learning_rate=0.001, loss=linear, n_estimators=408;, score=0.942 total time=  55.5s
# (PoolActor pid=569361, ip=10.19.0.100) [CV 3/5] END learning_rate=0.057857142857142864, loss=square, n_estimators=58;, score=0.938 total time=   7.6s
# (PoolActor pid=1672023, ip=192.168.124.155) [CV 3/5] END learning_rate=0.0862857142857143, loss=exponential, n_estimators=508;, score=0.658 total time= 1.0min
# (PoolActor pid=569444, ip=10.19.0.100) [CV 3/5] END learning_rate=0.2, loss=square, n_estimators=258;, score=0.170 total time=  26.2s
# (PoolActor pid=569373, ip=10.19.0.100) [CV 2/5] END learning_rate=0.057857142857142864, loss=exponential, n_estimators=358;, score=0.931 total time=  40.8s
# (PoolActor pid=569353, ip=10.19.0.100) [CV 1/5] END learning_rate=0.057857142857142864, loss=exponential, n_estimators=358;, score=0.930 total time=  47.2s
# (PoolActor pid=1672041, ip=192.168.124.155) [CV 1/5] END learning_rate=0.057857142857142864, loss=square, n_estimators=58;, score=0.940 total time=   6.7s [repeated 3x across cluster]
# (PoolActor pid=569492, ip=10.19.0.100) [CV 1/5] END learning_rate=0.0862857142857143, loss=linear, n_estimators=408;, score=0.941 total time=  27.7s
# (PoolActor pid=1672030, ip=192.168.124.155) [CV 1/5] END learning_rate=0.1715714285714286, loss=exponential, n_estimators=308;, score=0.537 total time=  29.1s
# (PoolActor pid=569378, ip=10.19.0.100) [CV 3/5] END learning_rate=0.001, loss=square, n_estimators=308;, score=0.932 total time=  46.3s [repeated 2x across cluster]
# (PoolActor pid=569369, ip=10.19.0.100) [CV 5/5] END learning_rate=0.1715714285714286, loss=linear, n_estimators=458;, score=0.942 total time=   9.9s
# (PoolActor pid=1672028, ip=192.168.124.155) [CV 2/5] END learning_rate=0.1715714285714286, loss=exponential, n_estimators=308;, score=0.809 total time=  27.5s [repeated 2x across cluster]
# (PoolActor pid=570137, ip=10.19.0.100) [CV 3/5] END learning_rate=0.0862857142857143, loss=linear, n_estimators=358;, score=0.936 total time=  18.4s
# (PoolActor pid=569367, ip=10.19.0.100) [CV 1/5] END learning_rate=0.029428571428571432, loss=square, n_estimators=508;, score=0.926 total time= 1.1min
# (PoolActor pid=569372, ip=10.19.0.100) [CV 3/5] END learning_rate=0.057857142857142864, loss=exponential, n_estimators=358;, score=0.916 total time=  50.9s [repeated 2x across cluster]
# (PoolActor pid=569375, ip=10.19.0.100) [CV 5/5] END learning_rate=0.0862857142857143, loss=linear, n_estimators=408;, score=0.941 total time=  47.0s
# (PoolActor pid=569376, ip=10.19.0.100) [CV 2/5] END learning_rate=0.2, loss=square, n_estimators=258;, score=0.830 total time=  24.1s
# (PoolActor pid=569377, ip=10.19.0.100) [CV 4/5] END learning_rate=0.2, loss=exponential, n_estimators=508;, score=-2.777 total time=  57.2s
# (PoolActor pid=569498, ip=10.19.0.100) [CV 3/5] END learning_rate=0.0862857142857143, loss=linear, n_estimators=408;, score=0.930 total time=  25.2s [repeated 2x across cluster]
# (PoolActor pid=569365, ip=10.19.0.100) [CV 4/5] END learning_rate=0.029428571428571432, loss=square, n_estimators=508;, score=0.930 total time= 1.1min
# (PoolActor pid=569354, ip=10.19.0.100) [CV 3/5] END learning_rate=0.057857142857142864, loss=exponential, n_estimators=508;, score=0.862 total time= 1.1min
# (PoolActor pid=570195, ip=10.19.0.100) [CV 3/5] END learning_rate=0.029428571428571432, loss=linear, n_estimators=208;, score=0.939 total time=  31.6s [repeated 3x across cluster]
# (PoolActor pid=1672036, ip=192.168.124.155) [CV 5/5] END learning_rate=0.029428571428571432, loss=square, n_estimators=508;, score=0.938 total time=  49.7s
# (PoolActor pid=569355, ip=10.19.0.100) [CV 2/5] END learning_rate=0.001, loss=exponential, n_estimators=408;, score=0.940 total time=  58.8s
# (PoolActor pid=569472, ip=10.19.0.100) [CV 2/5] END learning_rate=0.0862857142857143, loss=linear, n_estimators=408;, score=0.933 total time=  35.9s
# (PoolActor pid=569348, ip=10.19.0.100) [CV 3/5] END learning_rate=0.029428571428571432, loss=square, n_estimators=358;, score=0.928 total time=  47.5s
# (PoolActor pid=1672037, ip=192.168.124.155) [CV 4/5] END learning_rate=0.057857142857142864, loss=exponential, n_estimators=358;, score=0.933 total time=  36.0s
# (PoolActor pid=569382, ip=10.19.0.100) [CV 2/5] END learning_rate=0.14314285714285716, loss=square, n_estimators=108;, score=0.900 total time=  12.7s
# (PoolActor pid=569956, ip=10.19.0.100) [CV 3/5] END learning_rate=0.029428571428571432, loss=exponential, n_estimators=408;, score=0.938 total time=  57.7s
# (PoolActor pid=569381, ip=10.19.0.100) [CV 4/5] END learning_rate=0.14314285714285716, loss=square, n_estimators=108;, score=0.936 total time=  11.1s
# (PoolActor pid=569351, ip=10.19.0.100) [CV 2/5] END learning_rate=0.2, loss=exponential, n_estimators=8;, score=0.945 total time=   1.1s
# (PoolActor pid=569350, ip=10.19.0.100) [CV 2/5] END learning_rate=0.029428571428571432, loss=square, n_estimators=508;, score=0.920 total time= 1.0min
# (PoolActor pid=569363, ip=10.19.0.100) [CV 1/5] END learning_rate=0.029428571428571432, loss=linear, n_estimators=208;, score=0.944 total time=  25.1s
# (PoolActor pid=569609, ip=10.19.0.100) [CV 5/5] END learning_rate=0.001, loss=square, n_estimators=308;, score=0.938 total time=  41.2s [repeated 2x across cluster]
# (PoolActor pid=569438, ip=10.19.0.100) [CV 5/5] END learning_rate=0.2, loss=exponential, n_estimators=508;, score=-0.301 total time=  52.7s
# (PoolActor pid=570161, ip=10.19.0.100) [CV 3/5] END learning_rate=0.11471428571428573, loss=square, n_estimators=158;, score=0.903 total time=  18.0s [repeated 2x across cluster]
# (PoolActor pid=569347, ip=10.19.0.100) [CV 2/5] END learning_rate=0.029428571428571432, loss=exponential, n_estimators=258;, score=0.942 total time=  31.0s
# (PoolActor pid=569370, ip=10.19.0.100) [CV 1/5] END learning_rate=0.001, loss=linear, n_estimators=358;, score=0.948 total time=  41.7s
# (PoolActor pid=569499, ip=10.19.0.100) [CV 2/5] END learning_rate=0.001, loss=square, n_estimators=308;, score=0.939 total time=  35.5s
# (PoolActor pid=569348, ip=10.19.0.100) [CV 4/5] END learning_rate=0.029428571428571432, loss=exponential, n_estimators=258;, score=0.949 total time=  30.0s
# (PoolActor pid=569374, ip=10.19.0.100) [CV 2/5] END learning_rate=0.2, loss=exponential, n_estimators=508;, score=0.648 total time=  50.8s [repeated 2x across cluster]
# (PoolActor pid=569379, ip=10.19.0.100) [CV 1/5] END learning_rate=0.001, loss=linear, n_estimators=408;, score=0.947 total time=  49.4s
# (PoolActor pid=2571262) [CV 3/5] END .........alpha=0.08902150854450393;, score=0.949 total time=   0.2s
# (PoolActor pid=2571262) [CV 3/5] END ..........alpha=2420128.264794393;, score=-0.000 total time=   0.0s
