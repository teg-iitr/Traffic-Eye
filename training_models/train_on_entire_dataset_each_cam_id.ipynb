# %% [markdown]
# *For the final submission, the hyperparameter tuning of the best performing models (which were determined in initial training) is done with GridSearchCV, which fits all possible candidates in a search space. Thus giving the most optimal parameters. The model are then trained with these parameters on the entire dataset for each of the camera id* \
# For training the models, the same apporach explained in `train.ipynb` is used here.

# %% [markdown]
# ### Importing Dependencies

# %%
import os
import numpy as np
import pandas as pd
from pathlib import Path
from typing import Tuple

from sklearn.preprocessing import StandardScaler
from joblib import dump, load
from sklearn.model_selection import train_test_split

from cuml.linear_model import LinearRegression, Lasso, ElasticNet
from cuml.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor, AdaBoostRegressor
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import r2_score
from joblib import parallel_backend
from ray.util.joblib import register_ray
register_ray()
import ray
from cuml.common.device_selection import set_global_device_type

np.random.seed(42)

# %% [markdown]
# ### Connect to the ray cluster

# %%
set_global_device_type("GPU")
ray.init("auto")
# Out:
# 2024-08-25 10:55:37,428	INFO worker.py:1596 -- Connecting to existing Ray cluster at address: 10.19.3.211:6379...
# 2024-08-25 10:55:37,444	INFO worker.py:1772 -- Connected to Ray cluster. View the dashboard at 127.0.0.1:8265
# RayContext(dashboard_url='127.0.0.1:8265', python_version='3.10.12', ray_version='2.34.0', ray_commit='fc87217e031b4e551cbb3d3ffc75f8c0fb57886a')

# %%
dataset_dir = Path(r"/home/user1/codes/bangaluru_mobility_codes/submission/future_counts/data")
save_dir = Path(r"/home/user1/codes/bangaluru_mobility_codes/submission/future_counts/model_training/results_entire_dataset_each_cam_id")

# %%
acc_models = {"RandomForest","LinearRegression","Lasso","ElasticNet","XGBRegressor","CatBoostingRegressor"}
target_column = "count"

# %%
# Specify parameters and distributions to sample from for hyper-parameter tuning

params={
        "RandomForest":{
            'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
            'max_features':['sqrt','log2'],
            'n_estimators': [8,16,32,64,128,256,512,1024],
            'bootstrap': [False, True]
        },
        "GradientBoosting":{
            'loss':['squared_error', 'huber', 'absolute_error', 'quantile'],
            'learning_rate':[.1,.01,.05,.001],
            'subsample':[0.6,0.7,0.75,0.8,0.85,0.9],
            'criterion':['squared_error', 'friedman_mse'],
            'max_features':['sqrt','log2'],
            'n_estimators': [8,16,32,64,128,256]
        },
        "LinearRegression":{
            'algorithm': ['svd', 'eig', 'qr', 'svd-qr', 'svd-jacobi']
        },
        "XGBRegressor":{
            'learning_rate': np.linspace(0.001,0.2,8),
            'n_estimators': np.arange(8,512,50),
            'gamma': np.linspace(0,5,10),
            'reg_alpha': np.logspace(-3,1,10),
            'reg_lambda': np.logspace(-3,1,10)
        },
        "CatBoostingRegressor":{
            'depth': [4,6,8,10],
            'l2_leaf_reg': np.logspace(-2,1,10),
            'learning_rate': np.linspace(0.001,0.2,8),
            'iterations': np.arange(10,500,50)
        },
        "AdaBoostRegressor":{
            'learning_rate': np.linspace(0.001,0.2,8),
            'loss':['linear','square','exponential'],
            'n_estimators': np.arange(8,512,50),
        },
        "Lasso":{
            'alpha':  (np.logspace(-8, 8, 100)),
        },
        "ElasticNet": {
            'alpha': np.logspace(-4,2,30),
            'l1_ratio': np.linspace(0,1,30),
            'fit_intercept': [True, False]
        }
 }

# %%
def load_dateset(path: str) -> pd.DataFrame:
    """
    Load and preprocess a dataset from a CSV file.

    Removes any rows containing NaN values, and converts certain columns to more memory-efficient data types.
    The columns are then reordered for easier access.

    Parameters:
    path (str): The file path to the CSV file containing the dataset.

    Returns:
    pd.DataFrame
    """
    df = pd.read_csv(path)
    df = df.dropna()
    df["class"] = df["class"].astype(np.int8)
    df["zone_in"] = df["zone_in"].astype(np.int8)
    df["zone_out"] = df["zone_out"].astype(np.int8)
    df["count"] = df["count"].astype(np.int16)
    df["last_15_min_count"] = df["last_15_min_count"].astype(np.int16)
    df["last_30_min_count"] = df["last_30_min_count"].astype(np.int16)
    df = df.iloc[:,[0,1,2,4,5,3]]

    return df

# %%
def load_models(model_name: str):
    """
    Initializes and returns a machine learning models. 
    """
    models = {
        "ElasticNet": ElasticNet(copy_X=False),
        "XGBRegressor":XGBRegressor(),
        "LinearRegression":LinearRegression(copy_X=False),
        "RandomForest":RandomForestRegressor(),
        "GradientBoosting":GradientBoostingRegressor(),
        "CatBoostingRegressor":CatBoostRegressor(verbose=False),
        "AdaBoostRegressor":AdaBoostRegressor(),
        "Lasso": Lasso(copy_X=False),
    }

    return models[model_name]

# %%
def split_dataset(df: pd.DataFrame, cam_id: str) -> Tuple[np.ndarray, np.ndarray]:
    """
    Splits the dataset into matrix of features and dependent variable, scales the input features, and saves the scaler into a pickled file. 

    Parameters:
    -----------
    df (pd.DataFrame): The DataFrame containing the dataset to be split and scaled.
    
    cam_id (str): A unique identifier for the camera or dataset being processed. This ID is used to save the scaler with a specific name.

    Returns:
    --------
    Tuple[np.ndarray, np.ndarray]
    """
    scaler = StandardScaler()
    
    input_feature_train_df = df.drop([target_column], axis=1)
    target_feature_train_df = pd.DataFrame(df[target_column])

    input_feature_train_arr = scaler.fit_transform(input_feature_train_df)

    train_arr = np.c_[
        input_feature_train_arr, np.array(target_feature_train_df)
    ]

    dump(scaler, save_dir / "scalers" / f"{cam_id}.pkl")
    print(f"SC saved to {save_dir / 'scalers' / f'{cam_id}.pkl'}")

    X_train, y_train = train_arr[:, :-1], train_arr[:, -1]

    return X_train, y_train

# %%
model_for_location = {
    "18th_Crs_BsStp_JN_FIX_2": "GradientBoosting",
    "Ayyappa_Temple_FIX_1": "CatBoostingRegressor",
    "Stn_HD_1": "CatBoostingRegressor",
    "SBI_Bnk_JN_FIX_3": "CatBoostingRegressor",
    "Ramaiah_BsStp_JN_FIX_2": "CatBoostingRegressor",
    "Mattikere_JN_FIX_1": "GradientBoosting",
    "Buddha_Vihara_Temple": "XGBRegressor",
    "HP_Ptrl_Bnk_BEL_Rd_FIX_2": "CatBoostingRegressor",
    "Sundaranagar_Entrance": "GradientBoosting",
    "80ft_Road": "GradientBoosting",
    "Devasandra_Sgnl_JN_FIX_1": "CatBoostingRegressor",
    "Devasandra_Sgnl_JN_FIX_3": "CatBoostingRegressor",
    "Sty_Wll_Ldge_FIX_3": "GradientBoosting",
    "Ramaiah_BsStp_JN_FIX_1": "CatBoostingRegressor",
    "MS_Ramaiah_JN_FIX_1": "RandomForest",
    "MS_Ramaiah_JN_FIX_2": "CatBoostingRegressor",
    "18th_Crs_Bus_Stop_FIX_2": "CatBoostingRegressor",
    "SBI_Bnk_JN_FIX_1": "CatBoostingRegressor",
    "Mattikere_JN_FIX_3": "CatBoostingRegressor",
    "Mattikere_JN_HD_1": "Lasso",
    "Kuvempu_Circle_FIX_2": "RandomForest",
    "Kuvempu_Circle_FIX_1": "GradientBoosting",
    "Mattikere_JN_FIX_2": "GradientBoosting"
}

# %% [markdown]
# ### Train models

# %%
models_report = dict() # cam_id -> (model_score, model_name, parameters)

# Iterate over each dataset in the dataset directory
for file in os.listdir(dataset_dir):
    if not file.endswith(".csv"): continue

    cam_id = file.removesuffix(".csv")
    print(f"Training for {cam_id} ...")
    models_report[cam_id] = dict()
    
    # Load the dataset
    df = load_dateset(dataset_dir / file)

    # Scaler features and target variable
    X_train, y_train = split_dataset(df, cam_id)

    model_name = model_for_location[cam_id]
    
    # Initialize previous best performing model
    model = load_models(model_name)
    
    os.makedirs(save_dir / "models" / cam_id, exist_ok=True)
    print(f"Now evaluating: {model_name}\n\n")

    para = params[model_name]
    
    # Hyperparameter tuning for GPU supported models
    if model_name in acc_models:
        gs = GridSearchCV(model, para, cv=5, verbose=4, n_jobs=10)
        with parallel_backend('ray', ray_remote_args=dict(num_gpus=0.01)):
            gs.fit(X_train, y_train)
    else:
        # Hyperparameter tuning for non-GPU supported models
        gs = GridSearchCV(model, para, cv=5, verbose=4, n_jobs=-1)
        with parallel_backend('ray'):
            gs.fit(X_train, y_train)

        
    model.set_params(**gs.best_params_)
    # Fit the model with best parameters
    model.fit(X_train, y_train)

    model_score = gs.best_score_
    parameters = gs.best_params_
    
    # Save a pickled copy of the model
    dump(model, save_dir / "models" / cam_id / f"{model_name}.pkl")
    print(f"{model_name} saved to {save_dir / 'models' / cam_id}") 


    models_report[cam_id] = (model_score, model_name, parameters)
    
    print("Best model score and parameters:\n")
    print(models_report[cam_id])
    print("\n\n\n")
# Out:
# 2024-08-25 10:56:03,387	WARNING pool.py:589 -- The 'context' argument is not supported using ray. Please refer to the documentation for how to control ray initialization.
# Training for 18th_Crs_BsStp_JN_FIX_2 ...
# SC saved to /home/user1/codes/bangaluru_mobility_codes/submission/future_counts/model_training/results_entire_dataset_each_cam_id/scalers/18th_Crs_BsStp_JN_FIX_2.pkl
# [I] [10:56:03.213188] Unused keyword parameter: copy_X during cuML estimator initialization
# [I] [10:56:03.281393] Unused keyword parameter: copy_X during cuML estimator initialization
# Now evaluating: GradientBoosting
#
#
# Fitting 5 folds for each of 2304 candidates, totalling 11520 fits
# GradientBoosting saved to /home/user1/codes/bangaluru_mobility_codes/submission/future_counts/model_training/results_entire_dataset_each_cam_id/models/18th_Crs_BsStp_JN_FIX_2
# Best model score and parameters:
#
# (0.9375828231461629, 'GradientBoosting', {'criterion': 'friedman_mse', 'learning_rate': 0.1, 'loss': 'huber', 'max_features': 'sqrt', 'n_estimators': 64, 'subsample': 0.8})
#
#
#
#
# Training for Ayyappa_Temple_FIX_1 ...
# SC saved to /home/user1/codes/bangaluru_mobility_codes/submission/future_counts/model_training/results_entire_dataset_each_cam_id/scalers/Ayyappa_Temple_FIX_1.pkl
# [I] [10:57:02.400524] Unused keyword parameter: copy_X during cuML estimator initialization
# [I] [10:57:02.401024] Unused keyword parameter: copy_X during cuML estimator initialization
# Now evaluating: CatBoostingRegressor
#
#
# Fitting 5 folds for each of 3200 candidates, totalling 16000 fits
# (PoolActor pid=2752347) [CV 2/5] END criterion=squared_error, learning_rate=0.1, loss=squared_error, max_features=sqrt, n_estimators=8, subsample=0.6;, score=0.756 total time=   0.0s
# (PoolActor pid=2752428) [CV 1/5] END criterion=squared_error, learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=8, subsample=0.7;, score=0.766 total time=   0.0s
# (PoolActor pid=2752389) [CV 3/5] END criterion=squared_error, learning_rate=0.1, loss=huber, max_features=sqrt, n_estimators=8, subsample=0.8;, score=0.613 total time=   0.0s
# (PoolActor pid=2753067) [CV 5/5] END criterion=squared_error, learning_rate=0.1, loss=huber, max_features=log2, n_estimators=8, subsample=0.6;, score=0.547 total time=   0.0s
# (PoolActor pid=2753067) [CV 1/5] END criterion=squared_error, learning_rate=0.1, loss=huber, max_features=log2, n_estimators=8, subsample=0.7;, score=0.627 total time=   0.0s
# (PoolActor pid=2752382) [CV 1/5] END criterion=squared_error, learning_rate=0.1, loss=absolute_error, max_features=sqrt, n_estimators=8, subsample=0.85;, score=0.253 total time=   0.0s
# (PoolActor pid=2752382) [CV 2/5] END criterion=squared_error, learning_rate=0.1, loss=absolute_error, max_features=sqrt, n_estimators=8, subsample=0.85;, score=0.471 total time=   0.0s
# (PoolActor pid=2752382) [CV 3/5] END criterion=squared_error, learning_rate=0.1, loss=absolute_error, max_features=sqrt, n_estimators=8, subsample=0.85;, score=0.279 total time=   0.0s
# (PoolActor pid=2752382) [CV 4/5] END criterion=squared_error, learning_rate=0.1, loss=absolute_error, max_features=sqrt, n_estimators=8, subsample=0.85;, score=0.410 total time=   0.0s
# (PoolActor pid=2752433) [CV 5/5] END criterion=squared_error, learning_rate=0.1, loss=absolute_error, max_features=log2, n_estimators=8, subsample=0.6;, score=0.373 total time=   0.0s
# (PoolActor pid=2753500) [CV 1/5] END criterion=squared_error, learning_rate=0.1, loss=quantile, max_features=sqrt, n_estimators=8, subsample=0.6;, score=0.251 total time=   0.0s
# (PoolActor pid=2753500) [CV 2/5] END criterion=squared_error, learning_rate=0.1, loss=quantile, max_features=sqrt, n_estimators=8, subsample=0.6;, score=-0.338 total time=   0.0s
# (PoolActor pid=2753500) [CV 3/5] END criterion=squared_error, learning_rate=0.1, loss=quantile, max_features=sqrt, n_estimators=8, subsample=0.6;, score=0.350 total time=   0.0s
# (PoolActor pid=2752395) [CV 3/5] END criterion=squared_error, learning_rate=0.1, loss=quantile, max_features=log2, n_estimators=16, subsample=0.85;, score=0.699 total time=   0.0s
# (PoolActor pid=2752395) [CV 4/5] END criterion=squared_error, learning_rate=0.1, loss=quantile, max_features=log2, n_estimators=16, subsample=0.85;, score=0.614 total time=   0.0s
# (PoolActor pid=2752395) [CV 5/5] END criterion=squared_error, learning_rate=0.1, loss=quantile, max_features=log2, n_estimators=16, subsample=0.85;, score=0.629 total time=   0.0s
# (PoolActor pid=640545, ip=192.168.124.155) [CV 4/5] END criterion=squared_error, learning_rate=0.01, loss=squared_error, max_features=sqrt, n_estimators=32, subsample=0.6;, score=0.442 total time=   0.1s [repeated 249x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (PoolActor pid=850729, ip=10.19.0.100) [CV 5/5] END criterion=squared_error, learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=8, subsample=0.8;, score=0.708 total time=   0.0s [repeated 222x across cluster]
# (PoolActor pid=640543, ip=192.168.124.155) [CV 1/5] END criterion=squared_error, learning_rate=0.1, loss=huber, max_features=sqrt, n_estimators=8, subsample=0.9;, score=0.618 total time=   0.1s [repeated 186x across cluster]
# (PoolActor pid=2752486) [CV 2/5] END criterion=squared_error, learning_rate=0.05, loss=huber, max_features=log2, n_estimators=16, subsample=0.85;, score=0.659 total time=   0.0s [repeated 209x across cluster]
# (PoolActor pid=640529, ip=192.168.124.155) [CV 4/5] END criterion=squared_error, learning_rate=0.1, loss=absolute_error, max_features=sqrt, n_estimators=64, subsample=0.85;, score=0.954 total time=   0.2s [repeated 199x across cluster]
# (PoolActor pid=2752387) [CV 4/5] END criterion=squared_error, learning_rate=0.05, loss=absolute_error, max_features=log2, n_estimators=32, subsample=0.8;, score=0.699 total time=   0.1s [repeated 148x across cluster]
# (PoolActor pid=850726, ip=10.19.0.100) [CV 5/5] END criterion=squared_error, learning_rate=0.1, loss=quantile, max_features=sqrt, n_estimators=64, subsample=0.85;, score=0.861 total time=   0.2s [repeated 175x across cluster]
# (PoolActor pid=640535, ip=192.168.124.155) [CV 1/5] END criterion=squared_error, learning_rate=0.1, loss=quantile, max_features=log2, n_estimators=16, subsample=0.7;, score=0.726 total time=   0.1s [repeated 158x across cluster]
# (PoolActor pid=2753122) [CV 2/5] END criterion=friedman_mse, learning_rate=0.1, loss=squared_error, max_features=sqrt, n_estimators=16, subsample=0.9;, score=0.889 total time=   0.0s
# (PoolActor pid=2753122) [CV 3/5] END criterion=friedman_mse, learning_rate=0.1, loss=squared_error, max_features=sqrt, n_estimators=16, subsample=0.9;, score=0.890 total time=   0.0s
# (PoolActor pid=2753122) [CV 4/5] END criterion=friedman_mse, learning_rate=0.1, loss=squared_error, max_features=sqrt, n_estimators=16, subsample=0.9;, score=0.924 total time=   0.0s
# (PoolActor pid=2752625) [CV 2/5] END criterion=friedman_mse, learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=16, subsample=0.7;, score=0.896 total time=   0.0s
# (PoolActor pid=2752625) [CV 3/5] END criterion=friedman_mse, learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=16, subsample=0.7;, score=0.890 total time=   0.0s
# (PoolActor pid=2752625) [CV 4/5] END criterion=friedman_mse, learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=16, subsample=0.7;, score=0.926 total time=   0.0s
# (PoolActor pid=2752625) [CV 5/5] END criterion=friedman_mse, learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=16, subsample=0.7;, score=0.865 total time=   0.0s
# (PoolActor pid=2752625) [CV 1/5] END criterion=friedman_mse, learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=16, subsample=0.75;, score=0.922 total time=   0.0s
# (PoolActor pid=2752625) [CV 2/5] END criterion=friedman_mse, learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=16, subsample=0.75;, score=0.891 total time=   0.0s
# (PoolActor pid=2752625) [CV 3/5] END criterion=friedman_mse, learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=16, subsample=0.75;, score=0.887 total time=   0.0s
# (PoolActor pid=2752625) [CV 4/5] END criterion=friedman_mse, learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=16, subsample=0.75;, score=0.923 total time=   0.0s
# (PoolActor pid=2752625) [CV 5/5] END criterion=friedman_mse, learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=16, subsample=0.75;, score=0.864 total time=   0.0s
# (PoolActor pid=2752625) [CV 1/5] END criterion=friedman_mse, learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=16, subsample=0.8;, score=0.925 total time=   0.0s
# (PoolActor pid=2752625) [CV 2/5] END criterion=friedman_mse, learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=16, subsample=0.8;, score=0.891 total time=   0.0s
# (PoolActor pid=2752625) [CV 3/5] END criterion=friedman_mse, learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=16, subsample=0.8;, score=0.892 total time=   0.0s
# (PoolActor pid=2752625) [CV 4/5] END criterion=friedman_mse, learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=16, subsample=0.8;, score=0.925 total time=   0.0s
# (PoolActor pid=2752625) [CV 5/5] END criterion=friedman_mse, learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=16, subsample=0.8;, score=0.869 total time=   0.0s
# (PoolActor pid=2752389) [CV 4/5] END criterion=friedman_mse, learning_rate=0.1, loss=huber, max_features=sqrt, n_estimators=16, subsample=0.8;, score=0.878 total time=   0.0s
# (PoolActor pid=2752389) [CV 5/5] END criterion=friedman_mse, learning_rate=0.1, loss=huber, max_features=sqrt, n_estimators=16, subsample=0.8;, score=0.852 total time=   0.0s
# (PoolActor pid=2752389) [CV 1/5] END criterion=friedman_mse, learning_rate=0.1, loss=huber, max_features=sqrt, n_estimators=16, subsample=0.85;, score=0.860 total time=   0.0s
# (PoolActor pid=2753599) [CV 1/5] END criterion=friedman_mse, learning_rate=0.1, loss=huber, max_features=log2, n_estimators=32, subsample=0.6;, score=0.967 total time=   0.1s
# (PoolActor pid=2753599) [CV 2/5] END criterion=friedman_mse, learning_rate=0.1, loss=huber, max_features=log2, n_estimators=32, subsample=0.6;, score=0.911 total time=   0.1s
# (PoolActor pid=2752926) [CV 5/5] END criterion=friedman_mse, learning_rate=0.1, loss=absolute_error, max_features=sqrt, n_estimators=8, subsample=0.85;, score=0.393 total time=   0.0s
# (PoolActor pid=2752926) [CV 1/5] END criterion=friedman_mse, learning_rate=0.1, loss=absolute_error, max_features=sqrt, n_estimators=8, subsample=0.9;, score=0.330 total time=   0.0s
# (PoolActor pid=2752926) [CV 2/5] END criterion=friedman_mse, learning_rate=0.1, loss=absolute_error, max_features=sqrt, n_estimators=8, subsample=0.9;, score=0.535 total time=   0.0s
# (PoolActor pid=2752926) [CV 3/5] END criterion=friedman_mse, learning_rate=0.1, loss=absolute_error, max_features=sqrt, n_estimators=8, subsample=0.9;, score=0.282 total time=   0.0s
# (PoolActor pid=2752393) [CV 5/5] END criterion=friedman_mse, learning_rate=0.1, loss=absolute_error, max_features=log2, n_estimators=8, subsample=0.75;, score=0.299 total time=   0.0s
# (PoolActor pid=2752393) [CV 1/5] END criterion=friedman_mse, learning_rate=0.1, loss=absolute_error, max_features=log2, n_estimators=8, subsample=0.8;, score=0.380 total time=   0.0s
# (PoolActor pid=850714, ip=10.19.0.100) [CV 5/5] END criterion=squared_error, learning_rate=0.05, loss=squared_error, max_features=sqrt, n_estimators=16, subsample=0.7;, score=0.730 total time=   0.0s [repeated 246x across cluster]
# (PoolActor pid=850715, ip=10.19.0.100) [CV 5/5] END criterion=squared_error, learning_rate=0.01, loss=squared_error, max_features=log2, n_estimators=128, subsample=0.75;, score=0.839 total time=   0.2s [repeated 244x across cluster]
# (PoolActor pid=850760, ip=10.19.0.100) [CV 2/5] END criterion=squared_error, learning_rate=0.01, loss=huber, max_features=sqrt, n_estimators=32, subsample=0.6;, score=0.314 total time=   0.2s [repeated 232x across cluster]
# (PoolActor pid=640557, ip=192.168.124.155) [CV 3/5] END criterion=squared_error, learning_rate=0.01, loss=huber, max_features=log2, n_estimators=128, subsample=0.85;, score=0.782 total time=   0.9s [repeated 228x across cluster]
# (PoolActor pid=640530, ip=192.168.124.155) [CV 2/5] END criterion=squared_error, learning_rate=0.001, loss=absolute_error, max_features=sqrt, n_estimators=32, subsample=0.8;, score=-0.143 total time=   0.2s [repeated 257x across cluster]
# (PoolActor pid=2752625) [CV 1/5] END criterion=friedman_mse, learning_rate=0.1, loss=quantile, max_features=sqrt, n_estimators=8, subsample=0.75;, score=0.339 total time=   0.0s
# (PoolActor pid=2752625) [CV 2/5] END criterion=friedman_mse, learning_rate=0.1, loss=quantile, max_features=sqrt, n_estimators=8, subsample=0.75;, score=-0.308 total time=   0.0s
# (PoolActor pid=2752396) [CV 5/5] END criterion=squared_error, learning_rate=0.01, loss=absolute_error, max_features=log2, n_estimators=256, subsample=0.9;, score=0.838 total time=   0.5s [repeated 281x across cluster]
# (PoolActor pid=640525, ip=192.168.124.155) [CV 2/5] END criterion=squared_error, learning_rate=0.01, loss=quantile, max_features=sqrt, n_estimators=32, subsample=0.9;, score=-1.236 total time=   0.2s [repeated 272x across cluster]
# (PoolActor pid=640562, ip=192.168.124.155) [CV 4/5] END criterion=squared_error, learning_rate=0.05, loss=quantile, max_features=log2, n_estimators=64, subsample=0.9;, score=0.894 total time=   0.3s [repeated 295x across cluster]
# (PoolActor pid=850764, ip=10.19.0.100) [CV 5/5] END criterion=friedman_mse, learning_rate=0.1, loss=squared_error, max_features=sqrt, n_estimators=16, subsample=0.7;, score=0.859 total time=   0.0s [repeated 93x across cluster]
# (PoolActor pid=2752388) [CV 3/5] END criterion=friedman_mse, learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=256, subsample=0.9;, score=0.904 total time=   0.1s [repeated 64x across cluster]
# (PoolActor pid=2752871) [CV 2/5] END criterion=friedman_mse, learning_rate=0.1, loss=huber, max_features=sqrt, n_estimators=256, subsample=0.7;, score=0.928 total time=   0.3s [repeated 104x across cluster]
# (PoolActor pid=2752519) [CV 3/5] END criterion=friedman_mse, learning_rate=0.1, loss=quantile, max_features=log2, n_estimators=8, subsample=0.6;, score=0.230 total time=   0.0s
# (PoolActor pid=640558, ip=192.168.124.155) [CV 1/5] END criterion=friedman_mse, learning_rate=0.1, loss=huber, max_features=log2, n_estimators=32, subsample=0.9;, score=0.965 total time=   0.2s [repeated 61x across cluster]
# (PoolActor pid=850726, ip=10.19.0.100) [CV 1/5] END criterion=friedman_mse, learning_rate=0.1, loss=absolute_error, max_features=sqrt, n_estimators=32, subsample=0.75;, score=0.934 total time=   0.2s [repeated 103x across cluster]
# (PoolActor pid=640550, ip=192.168.124.155) [CV 3/5] END criterion=friedman_mse, learning_rate=0.1, loss=absolute_error, max_features=log2, n_estimators=128, subsample=0.85;, score=0.923 total time=   0.7s [repeated 79x across cluster]
# (PoolActor pid=640560, ip=192.168.124.155) [CV 3/5] END criterion=squared_error, learning_rate=0.001, loss=squared_error, max_features=sqrt, n_estimators=128, subsample=0.6;, score=0.202 total time=   0.2s [repeated 136x across cluster]
# (PoolActor pid=850723, ip=10.19.0.100) [CV 5/5] END criterion=squared_error, learning_rate=0.05, loss=squared_error, max_features=log2, n_estimators=32, subsample=0.7;, score=0.868 total time=   0.1s [repeated 106x across cluster]
# (PoolActor pid=850708, ip=10.19.0.100) [CV 4/5] END criterion=squared_error, learning_rate=0.001, loss=huber, max_features=sqrt, n_estimators=32, subsample=0.8;, score=-0.132 total time=   0.2s [repeated 169x across cluster]
# (PoolActor pid=850734, ip=10.19.0.100) [CV 4/5] END criterion=squared_error, learning_rate=0.05, loss=huber, max_features=log2, n_estimators=16, subsample=0.75;, score=0.674 total time=   0.1s [repeated 140x across cluster]
# (PoolActor pid=850717, ip=10.19.0.100) [CV 2/5] END criterion=squared_error, learning_rate=0.001, loss=absolute_error, max_features=sqrt, n_estimators=64, subsample=0.85;, score=-0.112 total time=   0.4s [repeated 92x across cluster]
# (PoolActor pid=850718, ip=10.19.0.100) [CV 4/5] END criterion=friedman_mse, learning_rate=0.1, loss=quantile, max_features=sqrt, n_estimators=256, subsample=0.9;, score=0.920 total time=   1.2s [repeated 86x across cluster]
# (PoolActor pid=850721, ip=10.19.0.100) [CV 3/5] END criterion=squared_error, learning_rate=0.05, loss=absolute_error, max_features=log2, n_estimators=64, subsample=0.75;, score=0.906 total time=   0.3s [repeated 94x across cluster]
# (PoolActor pid=850711, ip=10.19.0.100) [CV 3/5] END criterion=squared_error, learning_rate=0.01, loss=quantile, max_features=sqrt, n_estimators=128, subsample=0.9;, score=0.533 total time=   0.7s [repeated 129x across cluster]
# (PoolActor pid=850712, ip=10.19.0.100) [CV 3/5] END criterion=squared_error, learning_rate=0.01, loss=quantile, max_features=log2, n_estimators=8, subsample=0.85;, score=-0.929 total time=   0.0s [repeated 162x across cluster]
# (PoolActor pid=2752393) [CV 5/5] END criterion=friedman_mse, learning_rate=0.01, loss=squared_error, max_features=sqrt, n_estimators=128, subsample=0.9;, score=0.834 total time=   0.1s [repeated 75x across cluster]
# (PoolActor pid=640556, ip=192.168.124.155) [CV 3/5] END criterion=friedman_mse, learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=128, subsample=0.8;, score=0.906 total time=   0.2s [repeated 8x across cluster]
# (PoolActor pid=850722, ip=10.19.0.100) [CV 1/5] END criterion=friedman_mse, learning_rate=0.1, loss=huber, max_features=sqrt, n_estimators=64, subsample=0.7;, score=0.974 total time=   0.3s [repeated 21x across cluster]
# (PoolActor pid=850722, ip=10.19.0.100) [CV 4/5] END criterion=friedman_mse, learning_rate=0.1, loss=quantile, max_features=log2, n_estimators=8, subsample=0.85;, score=-0.139 total time=   0.0s [repeated 91x across cluster]
# (PoolActor pid=640561, ip=192.168.124.155) [CV 2/5] END criterion=friedman_mse, learning_rate=0.1, loss=huber, max_features=log2, n_estimators=128, subsample=0.6;, score=0.925 total time=   0.5s [repeated 48x across cluster]
# (PoolActor pid=850844, ip=10.19.0.100) [CV 1/5] END criterion=friedman_mse, learning_rate=0.1, loss=absolute_error, max_features=sqrt, n_estimators=64, subsample=0.9;, score=0.970 total time=   0.3s [repeated 22x across cluster]
# (PoolActor pid=850717, ip=10.19.0.100) [CV 2/5] END criterion=friedman_mse, learning_rate=0.1, loss=absolute_error, max_features=log2, n_estimators=32, subsample=0.9;, score=0.902 total time=   0.2s [repeated 30x across cluster]
# (PoolActor pid=850698, ip=10.19.0.100) [CV 2/5] END criterion=squared_error, learning_rate=0.05, loss=squared_error, max_features=sqrt, n_estimators=256, subsample=0.75;, score=0.929 total time=   0.5s [repeated 70x across cluster]
# (PoolActor pid=850692, ip=10.19.0.100) [CV 2/5] END criterion=squared_error, learning_rate=0.001, loss=squared_error, max_features=log2, n_estimators=64, subsample=0.8;, score=0.102 total time=   0.1s [repeated 76x across cluster]
# (PoolActor pid=640526, ip=192.168.124.155) [CV 4/5] END criterion=squared_error, learning_rate=0.001, loss=huber, max_features=sqrt, n_estimators=128, subsample=0.9;, score=0.032 total time=   0.6s [repeated 63x across cluster]
# (PoolActor pid=640528, ip=192.168.124.155) [CV 5/5] END criterion=squared_error, learning_rate=0.001, loss=huber, max_features=log2, n_estimators=128, subsample=0.75;, score=0.012 total time=   0.6s [repeated 69x across cluster]
# (PoolActor pid=640524, ip=192.168.124.155) [CV 3/5] END criterion=squared_error, learning_rate=0.01, loss=absolute_error, max_features=sqrt, n_estimators=256, subsample=0.75;, score=0.856 total time=   1.1s [repeated 90x across cluster]
# (PoolActor pid=850728, ip=10.19.0.100) [CV 4/5] END criterion=friedman_mse, learning_rate=0.1, loss=quantile, max_features=sqrt, n_estimators=256, subsample=0.6;, score=0.922 total time=   1.2s [repeated 33x across cluster]
# (PoolActor pid=850727, ip=10.19.0.100) [CV 5/5] END criterion=squared_error, learning_rate=0.001, loss=absolute_error, max_features=log2, n_estimators=128, subsample=0.75;, score=-0.103 total time=   0.5s [repeated 151x across cluster]
# (PoolActor pid=640557, ip=192.168.124.155) [CV 4/5] END criterion=squared_error, learning_rate=0.05, loss=quantile, max_features=sqrt, n_estimators=256, subsample=0.6;, score=0.917 total time=   0.9s [repeated 79x across cluster]
# (PoolActor pid=850716, ip=10.19.0.100) [CV 4/5] END criterion=squared_error, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=128, subsample=0.6;, score=-1.322 total time=   0.5s [repeated 66x across cluster]
# (PoolActor pid=640540, ip=192.168.124.155) [CV 1/5] END criterion=friedman_mse, learning_rate=0.1, loss=squared_error, max_features=sqrt, n_estimators=128, subsample=0.85;, score=0.974 total time=   0.2s [repeated 87x across cluster]
# (PoolActor pid=640539, ip=192.168.124.155) [CV 2/5] END criterion=friedman_mse, learning_rate=0.01, loss=squared_error, max_features=log2, n_estimators=256, subsample=0.9;, score=0.918 total time=   0.4s [repeated 204x across cluster]
# (PoolActor pid=850721, ip=10.19.0.100) [CV 4/5] END criterion=friedman_mse, learning_rate=0.01, loss=huber, max_features=sqrt, n_estimators=8, subsample=0.8;, score=-0.048 total time=   0.0s [repeated 119x across cluster]
# (PoolActor pid=850729, ip=10.19.0.100) [CV 4/5] END criterion=friedman_mse, learning_rate=0.1, loss=quantile, max_features=log2, n_estimators=256, subsample=0.9;, score=0.924 total time=   1.2s [repeated 45x across cluster]
# (PoolActor pid=640536, ip=192.168.124.155) [CV 1/5] END criterion=friedman_mse, learning_rate=0.01, loss=huber, max_features=log2, n_estimators=32, subsample=0.7;, score=0.228 total time=   0.1s [repeated 114x across cluster]
# (PoolActor pid=640560, ip=192.168.124.155) [CV 2/5] END criterion=friedman_mse, learning_rate=0.1, loss=absolute_error, max_features=sqrt, n_estimators=128, subsample=0.9;, score=0.921 total time=   0.5s [repeated 33x across cluster]
# (PoolActor pid=850716, ip=10.19.0.100) [CV 1/5] END criterion=friedman_mse, learning_rate=0.1, loss=absolute_error, max_features=log2, n_estimators=256, subsample=0.7;, score=0.971 total time=   0.9s [repeated 34x across cluster]
# (PoolActor pid=850698, ip=10.19.0.100) [CV 3/5] END criterion=squared_error, learning_rate=0.05, loss=squared_error, max_features=sqrt, n_estimators=256, subsample=0.8;, score=0.914 total time=   0.4s [repeated 6x across cluster]
# (PoolActor pid=640522, ip=192.168.124.155) [CV 4/5] END criterion=squared_error, learning_rate=0.001, loss=squared_error, max_features=log2, n_estimators=256, subsample=0.75;, score=0.370 total time=   0.4s [repeated 67x across cluster]
# (PoolActor pid=850710, ip=10.19.0.100) [CV 2/5] END criterion=squared_error, learning_rate=0.001, loss=huber, max_features=sqrt, n_estimators=128, subsample=0.7;, score=0.056 total time=   0.6s [repeated 31x across cluster]
# (PoolActor pid=640546, ip=192.168.124.155) [CV 2/5] END criterion=squared_error, learning_rate=0.001, loss=huber, max_features=log2, n_estimators=256, subsample=0.6;, score=0.231 total time=   1.1s [repeated 43x across cluster]
# (PoolActor pid=850704, ip=10.19.0.100) [CV 2/5] END criterion=squared_error, learning_rate=0.05, loss=absolute_error, max_features=sqrt, n_estimators=256, subsample=0.6;, score=0.918 total time=   0.9s [repeated 40x across cluster]
# (PoolActor pid=850719, ip=10.19.0.100) [CV 5/5] END criterion=friedman_mse, learning_rate=0.1, loss=quantile, max_features=sqrt, n_estimators=128, subsample=0.8;, score=0.865 total time=   0.5s [repeated 22x across cluster]
# (PoolActor pid=850814, ip=10.19.0.100) [CV 2/5] END criterion=squared_error, learning_rate=0.05, loss=absolute_error, max_features=log2, n_estimators=256, subsample=0.9;, score=0.918 total time=   1.0s [repeated 31x across cluster]
# (PoolActor pid=640543, ip=192.168.124.155) [CV 2/5] END criterion=squared_error, learning_rate=0.05, loss=quantile, max_features=sqrt, n_estimators=256, subsample=0.85;, score=0.858 total time=   0.9s [repeated 28x across cluster]
# (PoolActor pid=850757, ip=10.19.0.100) [CV 2/5] END criterion=squared_error, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=256, subsample=0.7;, score=-1.360 total time=   1.1s [repeated 13x across cluster]
# (PoolActor pid=850704, ip=10.19.0.100) [CV 2/5] END criterion=friedman_mse, learning_rate=0.1, loss=squared_error, max_features=sqrt, n_estimators=256, subsample=0.7;, score=0.923 total time=   0.4s [repeated 38x across cluster]
# (PoolActor pid=640544, ip=192.168.124.155) [CV 2/5] END criterion=friedman_mse, learning_rate=0.01, loss=squared_error, max_features=log2, n_estimators=32, subsample=0.9;, score=0.434 total time=   0.1s [repeated 20x across cluster]
# (PoolActor pid=640557, ip=192.168.124.155) [CV 2/5] END criterion=friedman_mse, learning_rate=0.1, loss=huber, max_features=sqrt, n_estimators=256, subsample=0.75;, score=0.931 total time=   1.0s [repeated 38x across cluster]
# (PoolActor pid=640544, ip=192.168.124.155) [CV 4/5] END criterion=friedman_mse, learning_rate=0.1, loss=quantile, max_features=log2, n_estimators=16, subsample=0.7;, score=0.631 total time=   0.1s [repeated 14x across cluster]
# (PoolActor pid=640559, ip=192.168.124.155) [CV 1/5] END criterion=friedman_mse, learning_rate=0.1, loss=huber, max_features=log2, n_estimators=256, subsample=0.8;, score=0.977 total time=   1.1s [repeated 88x across cluster]
# (PoolActor pid=850696, ip=10.19.0.100) [CV 4/5] END criterion=friedman_mse, learning_rate=0.01, loss=absolute_error, max_features=sqrt, n_estimators=128, subsample=0.7;, score=0.580 total time=   0.4s [repeated 158x across cluster]
# (PoolActor pid=640558, ip=192.168.124.155) [CV 4/5] END criterion=friedman_mse, learning_rate=0.01, loss=absolute_error, max_features=log2, n_estimators=256, subsample=0.9;, score=0.898 total time=   1.1s [repeated 155x across cluster]
# (PoolActor pid=640524, ip=192.168.124.155) [CV 5/5] END criterion=squared_error, learning_rate=0.001, loss=squared_error, max_features=sqrt, n_estimators=256, subsample=0.9;, score=0.359 total time=   0.3s [repeated 12x across cluster]
# (PoolActor pid=640524, ip=192.168.124.155) [CV 4/5] END criterion=squared_error, learning_rate=0.001, loss=squared_error, max_features=log2, n_estimators=8, subsample=0.6;, score=0.012 total time=   0.0s [repeated 4x across cluster]
# (PoolActor pid=640526, ip=192.168.124.155) [CV 3/5] END criterion=squared_error, learning_rate=0.001, loss=huber, max_features=sqrt, n_estimators=256, subsample=0.7;, score=0.176 total time=   1.1s [repeated 19x across cluster]
# (PoolActor pid=640547, ip=192.168.124.155) [CV 5/5] END criterion=squared_error, learning_rate=0.001, loss=huber, max_features=log2, n_estimators=256, subsample=0.75;, score=0.172 total time=   1.2s [repeated 19x across cluster]
# (PoolActor pid=640532, ip=192.168.124.155) [CV 3/5] END criterion=squared_error, learning_rate=0.001, loss=absolute_error, max_features=sqrt, n_estimators=256, subsample=0.8;, score=-0.021 total time=   0.9s [repeated 27x across cluster]
# (PoolActor pid=850693, ip=10.19.0.100) [CV 3/5] END criterion=friedman_mse, learning_rate=0.01, loss=quantile, max_features=sqrt, n_estimators=256, subsample=0.7;, score=0.858 total time=   1.0s [repeated 162x across cluster]
# (PoolActor pid=850814, ip=10.19.0.100) [CV 5/5] END criterion=squared_error, learning_rate=0.05, loss=absolute_error, max_features=log2, n_estimators=256, subsample=0.9;, score=0.894 total time=   0.9s [repeated 6x across cluster]
# (PoolActor pid=850733, ip=10.19.0.100) [CV 2/5] END criterion=squared_error, learning_rate=0.001, loss=quantile, max_features=sqrt, n_estimators=256, subsample=0.75;, score=-1.358 total time=   0.8s [repeated 15x across cluster]
# (PoolActor pid=850757, ip=10.19.0.100) [CV 2/5] END criterion=squared_error, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=256, subsample=0.75;, score=-1.348 total time=   0.9s [repeated 5x across cluster]
# (PoolActor pid=850712, ip=10.19.0.100) [CV 2/5] END criterion=friedman_mse, learning_rate=0.05, loss=squared_error, max_features=sqrt, n_estimators=256, subsample=0.8;, score=0.930 total time=   0.3s [repeated 176x across cluster]
# (PoolActor pid=640532, ip=192.168.124.155) [CV 5/5] END criterion=friedman_mse, learning_rate=0.01, loss=squared_error, max_features=log2, n_estimators=128, subsample=0.85;, score=0.832 total time=   0.2s [repeated 159x across cluster]
# (PoolActor pid=2753599) [CV 5/5] END criterion=friedman_mse, learning_rate=0.05, loss=huber, max_features=sqrt, n_estimators=256, subsample=0.85;, score=0.854 total time=   0.4s [repeated 156x across cluster]
# (PoolActor pid=2753122) [CV 3/5] END criterion=friedman_mse, learning_rate=0.05, loss=quantile, max_features=log2, n_estimators=8, subsample=0.75;, score=-0.228 total time=   0.0s [repeated 165x across cluster]
# (PoolActor pid=640523, ip=192.168.124.155) [CV 1/5] END criterion=friedman_mse, learning_rate=0.05, loss=huber, max_features=log2, n_estimators=64, subsample=0.7;, score=0.963 total time=   0.3s [repeated 119x across cluster]
# (PoolActor pid=850709, ip=10.19.0.100) [CV 1/5] END criterion=friedman_mse, learning_rate=0.05, loss=absolute_error, max_features=sqrt, n_estimators=8, subsample=0.9;, score=0.086 total time=   0.0s [repeated 91x across cluster]
# (PoolActor pid=850704, ip=10.19.0.100) [CV 5/5] END criterion=friedman_mse, learning_rate=0.01, loss=absolute_error, max_features=log2, n_estimators=128, subsample=0.9;, score=0.501 total time=   0.5s [repeated 108x across cluster]
# (PoolActor pid=850711, ip=10.19.0.100) [CV 5/5] END criterion=squared_error, learning_rate=0.001, loss=huber, max_features=sqrt, n_estimators=256, subsample=0.75;, score=0.172 total time=   1.1s [repeated 8x across cluster]
# (PoolActor pid=640547, ip=192.168.124.155) [CV 4/5] END criterion=squared_error, learning_rate=0.001, loss=huber, max_features=log2, n_estimators=256, subsample=0.8;, score=0.207 total time=   1.1s [repeated 7x across cluster]
# (PoolActor pid=850698, ip=10.19.0.100) [CV 5/5] END criterion=squared_error, learning_rate=0.001, loss=absolute_error, max_features=sqrt, n_estimators=256, subsample=0.9;, score=-0.015 total time=   0.9s [repeated 11x across cluster]
# (PoolActor pid=850716, ip=10.19.0.100) [CV 5/5] END criterion=friedman_mse, learning_rate=0.05, loss=quantile, max_features=sqrt, n_estimators=128, subsample=0.7;, score=0.859 total time=   0.7s [repeated 150x across cluster]
# (PoolActor pid=850698, ip=10.19.0.100) [CV 4/5] END criterion=squared_error, learning_rate=0.001, loss=absolute_error, max_features=log2, n_estimators=8, subsample=0.6;, score=-0.186 total time=   0.0s [repeated 8x across cluster]
# (PoolActor pid=850733, ip=10.19.0.100) [CV 2/5] END criterion=squared_error, learning_rate=0.001, loss=quantile, max_features=sqrt, n_estimators=256, subsample=0.8;, score=-1.345 total time=   0.9s [repeated 10x across cluster]
# (PoolActor pid=850760, ip=10.19.0.100) [CV 1/5] END criterion=squared_error, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=256, subsample=0.9;, score=-0.432 total time=   1.3s [repeated 9x across cluster]
# (PoolActor pid=850724, ip=10.19.0.100) [CV 5/5] END criterion=friedman_mse, learning_rate=0.001, loss=squared_error, max_features=sqrt, n_estimators=32, subsample=0.9;, score=0.055 total time=   0.1s [repeated 176x across cluster]
# (PoolActor pid=850698, ip=10.19.0.100) [CV 3/5] END criterion=friedman_mse, learning_rate=0.05, loss=squared_error, max_features=log2, n_estimators=32, subsample=0.7;, score=0.885 total time=   0.0s [repeated 190x across cluster]
# (PoolActor pid=640524, ip=192.168.124.155) [CV 4/5] END criterion=friedman_mse, learning_rate=0.001, loss=huber, max_features=sqrt, n_estimators=256, subsample=0.8;, score=0.204 total time=   1.2s [repeated 185x across cluster]
# (PoolActor pid=640555, ip=192.168.124.155) [CV 3/5] END criterion=friedman_mse, learning_rate=0.01, loss=quantile, max_features=log2, n_estimators=256, subsample=0.6;, score=0.854 total time=   0.9s [repeated 164x across cluster]
# (PoolActor pid=850692, ip=10.19.0.100) [CV 2/5] END criterion=friedman_mse, learning_rate=0.05, loss=huber, max_features=log2, n_estimators=128, subsample=0.75;, score=0.926 total time=   0.6s [repeated 166x across cluster]
# (PoolActor pid=2752384) [CV 1/5] END criterion=friedman_mse, learning_rate=0.001, loss=absolute_error, max_features=sqrt, n_estimators=8, subsample=0.7;, score=-0.214 total time=   0.0s [repeated 97x across cluster]
# (PoolActor pid=850728, ip=10.19.0.100) [CV 3/5] END criterion=friedman_mse, learning_rate=0.05, loss=absolute_error, max_features=log2, n_estimators=256, subsample=0.8;, score=0.916 total time=   0.9s [repeated 105x across cluster]
# (PoolActor pid=850711, ip=10.19.0.100) [CV 4/5] END criterion=squared_error, learning_rate=0.001, loss=huber, max_features=sqrt, n_estimators=256, subsample=0.8;, score=0.208 total time=   1.2s [repeated 4x across cluster]
# (PoolActor pid=640547, ip=192.168.124.155) [CV 2/5] END criterion=squared_error, learning_rate=0.001, loss=huber, max_features=log2, n_estimators=256, subsample=0.85;, score=0.230 total time=   1.1s [repeated 3x across cluster]
# (PoolActor pid=640547, ip=192.168.124.155) [CV 5/5] END criterion=friedman_mse, learning_rate=0.01, loss=quantile, max_features=sqrt, n_estimators=16, subsample=0.8;, score=-0.697 total time=   0.1s [repeated 40x across cluster]
# (PoolActor pid=850733, ip=10.19.0.100) [CV 2/5] END criterion=squared_error, learning_rate=0.001, loss=quantile, max_features=sqrt, n_estimators=256, subsample=0.85;, score=-1.372 total time=   1.0s [repeated 5x across cluster]
# (PoolActor pid=850757, ip=10.19.0.100) [CV 2/5] END criterion=squared_error, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=256, subsample=0.85;, score=-1.373 total time=   0.9s [repeated 9x across cluster]
# (PoolActor pid=640557, ip=192.168.124.155) [CV 3/5] END criterion=friedman_mse, learning_rate=0.01, loss=squared_error, max_features=sqrt, n_estimators=64, subsample=0.7;, score=0.661 total time=   0.1s [repeated 43x across cluster]
# (PoolActor pid=850715, ip=10.19.0.100) [CV 2/5] END criterion=friedman_mse, learning_rate=0.05, loss=squared_error, max_features=log2, n_estimators=256, subsample=0.6;, score=0.929 total time=   0.3s [repeated 38x across cluster]
# (PoolActor pid=640543, ip=192.168.124.155) [CV 5/5] END criterion=friedman_mse, learning_rate=0.05, loss=huber, max_features=sqrt, n_estimators=256, subsample=0.7;, score=0.851 total time=   1.0s [repeated 58x across cluster]
# (PoolActor pid=2752386) [CV 1/5] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=8, subsample=0.9;, score=-0.960 total time=   0.0s [repeated 60x across cluster]
# (PoolActor pid=640545, ip=192.168.124.155) [CV 3/5] END criterion=friedman_mse, learning_rate=0.001, loss=huber, max_features=log2, n_estimators=8, subsample=0.85;, score=-0.218 total time=   0.1s [repeated 92x across cluster]
# (PoolActor pid=640559, ip=192.168.124.155) [CV 3/5] END criterion=friedman_mse, learning_rate=0.001, loss=absolute_error, max_features=sqrt, n_estimators=32, subsample=0.7;, score=-0.204 total time=   0.1s [repeated 162x across cluster]
# (PoolActor pid=850722, ip=10.19.0.100) [CV 4/5] END criterion=friedman_mse, learning_rate=0.001, loss=absolute_error, max_features=log2, n_estimators=128, subsample=0.85;, score=-0.079 total time=   0.5s [repeated 152x across cluster]
# (PoolActor pid=850711, ip=10.19.0.100) [CV 4/5] END criterion=squared_error, learning_rate=0.001, loss=huber, max_features=sqrt, n_estimators=256, subsample=0.85;, score=0.209 total time=   1.0s [repeated 5x across cluster]
# (PoolActor pid=850691, ip=10.19.0.100) [CV 3/5] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=sqrt, n_estimators=128, subsample=0.75;, score=-0.792 total time=   0.5s [repeated 157x across cluster]
# (PoolActor pid=850733, ip=10.19.0.100) [CV 1/5] END criterion=squared_error, learning_rate=0.001, loss=quantile, max_features=sqrt, n_estimators=256, subsample=0.9;, score=-0.439 total time=   0.8s [repeated 4x across cluster]
# (PoolActor pid=850733, ip=10.19.0.100) [CV 3/5] END criterion=friedman_mse, learning_rate=0.01, loss=squared_error, max_features=sqrt, n_estimators=8, subsample=0.7;, score=0.131 total time=   0.0s [repeated 16x across cluster]
# (PoolActor pid=850733, ip=10.19.0.100) [CV 3/5] END criterion=friedman_mse, learning_rate=0.01, loss=squared_error, max_features=log2, n_estimators=256, subsample=0.8;, score=0.922 total time=   0.3s [repeated 14x across cluster]
# (PoolActor pid=640557, ip=192.168.124.155) [CV 3/5] END criterion=friedman_mse, learning_rate=0.05, loss=huber, max_features=sqrt, n_estimators=256, subsample=0.6;, score=0.920 total time=   0.9s [repeated 25x across cluster]
# (PoolActor pid=850697, ip=10.19.0.100) [CV 5/5] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=64, subsample=0.9;, score=-0.940 total time=   0.2s [repeated 167x across cluster]
# (PoolActor pid=850711, ip=10.19.0.100) [CV 5/5] END criterion=friedman_mse, learning_rate=0.01, loss=huber, max_features=log2, n_estimators=16, subsample=0.6;, score=0.055 total time=   0.1s [repeated 21x across cluster]
# (PoolActor pid=850733, ip=10.19.0.100) [CV 1/5] END criterion=friedman_mse, learning_rate=0.01, loss=absolute_error, max_features=sqrt, n_estimators=16, subsample=0.7;, score=-0.094 total time=   0.1s [repeated 31x across cluster]
# (PoolActor pid=850814, ip=10.19.0.100) [CV 4/5] END criterion=friedman_mse, learning_rate=0.001, loss=absolute_error, max_features=log2, n_estimators=128, subsample=0.8;, score=-0.079 total time=   0.4s [repeated 46x across cluster]
# (PoolActor pid=850711, ip=10.19.0.100) [CV 1/5] END criterion=squared_error, learning_rate=0.001, loss=huber, max_features=sqrt, n_estimators=256, subsample=0.9;, score=0.158 total time=   1.1s [repeated 2x across cluster]
# (PoolActor pid=850760, ip=10.19.0.100) [CV 5/5] END criterion=friedman_mse, learning_rate=0.05, loss=quantile, max_features=sqrt, n_estimators=256, subsample=0.75;, score=0.865 total time=   0.8s [repeated 47x across cluster]
# (PoolActor pid=850711, ip=10.19.0.100) [CV 1/5] END criterion=friedman_mse, learning_rate=0.05, loss=squared_error, max_features=sqrt, n_estimators=256, subsample=0.7;, score=0.975 total time=   0.3s [repeated 13x across cluster]
# (PoolActor pid=850733, ip=10.19.0.100) [CV 4/5] END criterion=friedman_mse, learning_rate=0.001, loss=squared_error, max_features=log2, n_estimators=128, subsample=0.85;, score=0.207 total time=   0.2s [repeated 7x across cluster]
# (PoolActor pid=850733, ip=10.19.0.100) [CV 5/5] END criterion=friedman_mse, learning_rate=0.001, loss=huber, max_features=sqrt, n_estimators=64, subsample=0.7;, score=-0.089 total time=   0.2s [repeated 9x across cluster]
# (PoolActor pid=850733, ip=10.19.0.100) [CV 1/5] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=8, subsample=0.8;, score=-0.957 total time=   0.0s [repeated 7x across cluster]
# (PoolActor pid=850733, ip=10.19.0.100) [CV 1/5] END criterion=friedman_mse, learning_rate=0.001, loss=huber, max_features=log2, n_estimators=16, subsample=0.9;, score=-0.192 total time=   0.1s [repeated 7x across cluster]
# (PoolActor pid=850760, ip=10.19.0.100) [CV 4/5] END criterion=friedman_mse, learning_rate=0.001, loss=absolute_error, max_features=sqrt, n_estimators=8, subsample=0.85;, score=-0.187 total time=   0.0s [repeated 16x across cluster]
# (PoolActor pid=850733, ip=10.19.0.100) [CV 4/5] END criterion=friedman_mse, learning_rate=0.001, loss=absolute_error, max_features=log2, n_estimators=64, subsample=0.75;, score=-0.134 total time=   0.2s [repeated 7x across cluster]
# (PoolActor pid=850757, ip=10.19.0.100) [CV 1/5] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=sqrt, n_estimators=32, subsample=0.75;, score=-0.896 total time=   0.1s [repeated 21x across cluster]
# (PoolActor pid=2759680) [CV 3/5] END depth=4, iterations=10, l2_leaf_reg=0.01, learning_rate=0.029428571428571432;, score=0.406 total time=   0.1s
# (PoolActor pid=2759680) [CV 3/5] END depth=4, iterations=10, l2_leaf_reg=0.01, learning_rate=0.0862857142857143;, score=0.771 total time=   0.0s
# (PoolActor pid=850757, ip=10.19.0.100) [CV 5/5] END criterion=friedman_mse, learning_rate=0.001, loss=squared_error, max_features=log2, n_estimators=256, subsample=0.6;, score=0.360 total time=   0.3s [repeated 2x across cluster]
# (PoolActor pid=850757, ip=10.19.0.100) [CV 1/5] END criterion=friedman_mse, learning_rate=0.001, loss=huber, max_features=sqrt, n_estimators=64, subsample=0.85;, score=-0.107 total time=   0.2s [repeated 2x across cluster]
# (PoolActor pid=850757, ip=10.19.0.100) [CV 3/5] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=256, subsample=0.75;, score=-0.524 total time=   0.8s [repeated 6x across cluster]
# (PoolActor pid=850757, ip=10.19.0.100) [CV 2/5] END criterion=friedman_mse, learning_rate=0.001, loss=huber, max_features=log2, n_estimators=32, subsample=0.7;, score=-0.112 total time=   0.1s [repeated 2x across cluster]
# (PoolActor pid=850757, ip=10.19.0.100) [CV 4/5] END criterion=friedman_mse, learning_rate=0.001, loss=absolute_error, max_features=sqrt, n_estimators=256, subsample=0.7;, score=0.023 total time=   0.8s [repeated 3x across cluster]
# (PoolActor pid=850757, ip=10.19.0.100) [CV 5/5] END criterion=friedman_mse, learning_rate=0.001, loss=absolute_error, max_features=log2, n_estimators=64, subsample=0.85;, score=-0.151 total time=   0.2s [repeated 2x across cluster]
# (PoolActor pid=2759674) [CV 1/5] END depth=4, iterations=110, l2_leaf_reg=0.01, learning_rate=0.11471428571428573;, score=0.964 total time=   0.1s [repeated 823x across cluster]
# (PoolActor pid=2759674) [CV 4/5] END depth=4, iterations=160, l2_leaf_reg=0.046415888336127774, learning_rate=0.11471428571428573;, score=0.965 total time=   0.1s [repeated 502x across cluster]
# (PoolActor pid=2759678) [CV 2/5] END depth=4, iterations=210, l2_leaf_reg=0.09999999999999999, learning_rate=0.0862857142857143;, score=0.952 total time=   0.1s [repeated 407x across cluster]
# (PoolActor pid=2759674) [CV 2/5] END depth=4, iterations=260, l2_leaf_reg=0.046415888336127774, learning_rate=0.11471428571428573;, score=0.952 total time=   0.1s [repeated 360x across cluster]
# (PoolActor pid=2759678) [CV 1/5] END depth=4, iterations=310, l2_leaf_reg=0.01, learning_rate=0.14314285714285716;, score=0.955 total time=   0.2s [repeated 323x across cluster]
# (PoolActor pid=2759678) [CV 1/5] END depth=4, iterations=310, l2_leaf_reg=2.154434690031882, learning_rate=0.14314285714285716;, score=0.962 total time=   0.2s [repeated 280x across cluster]
# (PoolActor pid=2759672) [CV 5/5] END depth=4, iterations=360, l2_leaf_reg=0.09999999999999999, learning_rate=0.0862857142857143;, score=0.938 total time=   0.2s [repeated 257x across cluster]
# (PoolActor pid=2759680) [CV 3/5] END depth=4, iterations=360, l2_leaf_reg=10.0, learning_rate=0.14314285714285716;, score=0.916 total time=   0.2s [repeated 234x across cluster]
# (PoolActor pid=2759674) [CV 2/5] END depth=4, iterations=410, l2_leaf_reg=0.4641588833612777, learning_rate=0.11471428571428573;, score=0.948 total time=   0.3s [repeated 222x across cluster]
# (PoolActor pid=2759674) [CV 2/5] END depth=4, iterations=460, l2_leaf_reg=0.01, learning_rate=0.1715714285714286;, score=0.939 total time=   0.3s [repeated 210x across cluster]
# (PoolActor pid=2759672) [CV 5/5] END depth=4, iterations=460, l2_leaf_reg=0.21544346900318834, learning_rate=0.0862857142857143;, score=0.939 total time=   0.2s [repeated 183x across cluster]
# (PoolActor pid=2759674) [CV 2/5] END depth=6, iterations=10, l2_leaf_reg=0.01, learning_rate=0.057857142857142864;, score=0.641 total time=   0.1s [repeated 191x across cluster]
# (PoolActor pid=2759674) [CV 5/5] END depth=6, iterations=60, l2_leaf_reg=4.641588833612777, learning_rate=0.1715714285714286;, score=0.952 total time=   0.1s [repeated 729x across cluster]
# (PoolActor pid=2759674) [CV 2/5] END depth=6, iterations=110, l2_leaf_reg=10.0, learning_rate=0.2;, score=0.948 total time=   0.1s [repeated 455x across cluster]
# (PoolActor pid=2759674) [CV 3/5] END depth=6, iterations=160, l2_leaf_reg=2.154434690031882, learning_rate=0.2;, score=0.913 total time=   0.2s [repeated 340x across cluster]
# (PoolActor pid=2759672) [CV 2/5] END depth=6, iterations=210, l2_leaf_reg=0.21544346900318834, learning_rate=0.14314285714285716;, score=0.941 total time=   0.2s [repeated 276x across cluster]
# (PoolActor pid=2759674) [CV 3/5] END depth=6, iterations=260, l2_leaf_reg=0.01, learning_rate=0.2;, score=0.905 total time=   0.3s [repeated 244x across cluster]
# (PoolActor pid=2759674) [CV 2/5] END depth=6, iterations=260, l2_leaf_reg=1.0, learning_rate=0.057857142857142864;, score=0.950 total time=   0.3s [repeated 210x across cluster]
# (PoolActor pid=2759674) [CV 2/5] END depth=6, iterations=310, l2_leaf_reg=0.021544346900318832, learning_rate=0.11471428571428573;, score=0.941 total time=   0.2s [repeated 204x across cluster]
# (PoolActor pid=2759680) [CV 3/5] END depth=6, iterations=310, l2_leaf_reg=1.0, learning_rate=0.0862857142857143;, score=0.915 total time=   0.2s [repeated 195x across cluster]
# (PoolActor pid=2759672) [CV 5/5] END depth=6, iterations=360, l2_leaf_reg=0.01, learning_rate=0.0862857142857143;, score=0.941 total time=   0.3s [repeated 183x across cluster]
# (PoolActor pid=2759672) [CV 5/5] END depth=6, iterations=360, l2_leaf_reg=0.21544346900318834, learning_rate=0.029428571428571432;, score=0.944 total time=   0.4s [repeated 161x across cluster]
# (PoolActor pid=2759679) [CV 2/5] END depth=6, iterations=360, l2_leaf_reg=10.0, learning_rate=0.029428571428571432;, score=0.951 total time=   0.2s [repeated 168x across cluster]
# (PoolActor pid=2759674) [CV 2/5] END depth=6, iterations=410, l2_leaf_reg=0.09999999999999999, learning_rate=0.001;, score=0.512 total time=   0.3s [repeated 150x across cluster]
# (PoolActor pid=2759674) [CV 2/5] END depth=6, iterations=410, l2_leaf_reg=1.0, learning_rate=0.11471428571428573;, score=0.943 total time=   0.3s [repeated 144x across cluster]
# (PoolActor pid=2759675) [CV 3/5] END depth=6, iterations=460, l2_leaf_reg=0.01, learning_rate=0.001;, score=0.554 total time=   0.4s [repeated 143x across cluster]
# (PoolActor pid=2759681) [CV 4/5] END depth=6, iterations=460, l2_leaf_reg=0.046415888336127774, learning_rate=0.2;, score=0.956 total time=   0.4s [repeated 124x across cluster]
# (PoolActor pid=2759676) [CV 4/5] END depth=6, iterations=460, l2_leaf_reg=1.0, learning_rate=0.001;, score=0.542 total time=   0.4s [repeated 125x across cluster]
# (PoolActor pid=2759680) [CV 3/5] END depth=6, iterations=460, l2_leaf_reg=10.0, learning_rate=0.0862857142857143;, score=0.910 total time=   0.4s [repeated 127x across cluster]
# (PoolActor pid=2759674) [CV 5/5] END depth=8, iterations=60, l2_leaf_reg=0.21544346900318834, learning_rate=0.11471428571428573;, score=0.949 total time=   0.1s [repeated 581x across cluster]
# (PoolActor pid=2759674) [CV 1/5] END depth=8, iterations=110, l2_leaf_reg=0.09999999999999999, learning_rate=0.14314285714285716;, score=0.964 total time=   0.2s [repeated 382x across cluster]
# (PoolActor pid=2759678) [CV 3/5] END depth=8, iterations=160, l2_leaf_reg=0.01, learning_rate=0.001;, score=0.253 total time=   0.3s [repeated 280x across cluster]
# ...
# (PoolActor pid=946304, ip=10.19.0.100) [CV 5/5] END criterion=friedman_mse, learning_rate=0.001, loss=huber, max_features=log2, n_estimators=8, subsample=0.75;, score=-0.060 total time=   0.1s [repeated 6x across cluster]
# (PoolActor pid=946322, ip=10.19.0.100) [CV 3/5] END criterion=friedman_mse, learning_rate=0.001, loss=huber, max_features=sqrt, n_estimators=32, subsample=0.8;, score=-0.049 total time=   0.2s [repeated 6x across cluster]
# (PoolActor pid=1556104, ip=192.168.124.155) [CV 3/5] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=sqrt, n_estimators=8, subsample=0.6;, score=0.008 total time=   0.1s [repeated 49x across cluster]
# (PoolActor pid=1421468) [CV 5/5] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=8, subsample=0.6;, score=0.008 total time=   0.0s [repeated 5x across cluster]
# (PoolActor pid=946328, ip=10.19.0.100) [CV 3/5] END criterion=friedman_mse, learning_rate=0.001, loss=squared_error, max_features=sqrt, n_estimators=16, subsample=0.8;, score=0.028 total time=   0.0s [repeated 2x across cluster]
# (PoolActor pid=946276, ip=10.19.0.100) [CV 3/5] END criterion=friedman_mse, learning_rate=0.05, loss=absolute_error, max_features=sqrt, n_estimators=32, subsample=0.6;, score=-0.065 total time=   0.1s [repeated 12x across cluster]
# (PoolActor pid=946385, ip=10.19.0.100) [CV 2/5] END criterion=friedman_mse, learning_rate=0.001, loss=absolute_error, max_features=log2, n_estimators=256, subsample=0.8;, score=-0.061 total time=   0.5s [repeated 29x across cluster]
# (PoolActor pid=946328, ip=10.19.0.100) [CV 5/5] END criterion=friedman_mse, learning_rate=0.001, loss=squared_error, max_features=log2, n_estimators=128, subsample=0.8;, score=0.199 total time=   0.4s [repeated 3x across cluster]
# (PoolActor pid=946276, ip=10.19.0.100) [CV 2/5] END criterion=friedman_mse, learning_rate=0.05, loss=huber, max_features=log2, n_estimators=64, subsample=0.8;, score=0.925 total time=   0.4s [repeated 7x across cluster]
# (PoolActor pid=946276, ip=10.19.0.100) [CV 1/5] END criterion=friedman_mse, learning_rate=0.001, loss=huber, max_features=sqrt, n_estimators=32, subsample=0.75;, score=-0.047 total time=   0.2s [repeated 5x across cluster]
# (PoolActor pid=1556143, ip=192.168.124.155) [CV 4/5] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=sqrt, n_estimators=64, subsample=0.75;, score=0.140 total time=   0.3s [repeated 67x across cluster]
# (PoolActor pid=1421462) [CV 1/5] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=64, subsample=0.9;, score=0.122 total time=   0.1s [repeated 40x across cluster]
# (PoolActor pid=946276, ip=10.19.0.100) [CV 4/5] END criterion=friedman_mse, learning_rate=0.001, loss=squared_error, max_features=sqrt, n_estimators=256, subsample=0.7;, score=0.396 total time=   0.7s [repeated 2x across cluster]
# (PoolActor pid=946280, ip=10.19.0.100) [CV 2/5] END criterion=friedman_mse, learning_rate=0.001, loss=absolute_error, max_features=sqrt, n_estimators=128, subsample=0.85;, score=-0.061 total time=   0.3s [repeated 4x across cluster]
# (PoolActor pid=946280, ip=10.19.0.100) [CV 3/5] END criterion=friedman_mse, learning_rate=0.001, loss=absolute_error, max_features=log2, n_estimators=64, subsample=0.7;, score=-0.065 total time=   0.2s [repeated 6x across cluster]
# (PoolActor pid=946276, ip=10.19.0.100) [CV 5/5] END criterion=friedman_mse, learning_rate=0.001, loss=squared_error, max_features=log2, n_estimators=64, subsample=0.85;, score=0.105 total time=   0.2s
# (PoolActor pid=946323, ip=10.19.0.100) [CV 5/5] END criterion=friedman_mse, learning_rate=0.001, loss=huber, max_features=log2, n_estimators=256, subsample=0.85;, score=0.058 total time=   1.7s [repeated 6x across cluster]
# (PoolActor pid=946361, ip=10.19.0.100) [CV 4/5] END criterion=friedman_mse, learning_rate=0.001, loss=huber, max_features=sqrt, n_estimators=256, subsample=0.7;, score=0.078 total time=   1.7s
# (PoolActor pid=946317, ip=10.19.0.100) [CV 3/5] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=sqrt, n_estimators=32, subsample=0.6;, score=0.059 total time=   0.2s [repeated 35x across cluster]
# (PoolActor pid=1556128, ip=192.168.124.155) [CV 4/5] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=32, subsample=0.9;, score=0.058 total time=   0.2s [repeated 57x across cluster]
# (PoolActor pid=946323, ip=10.19.0.100) [CV 1/5] END criterion=friedman_mse, learning_rate=0.001, loss=absolute_error, max_features=sqrt, n_estimators=128, subsample=0.75;, score=-0.064 total time=   0.3s
# (PoolActor pid=946271, ip=10.19.0.100) [CV 4/5] END criterion=friedman_mse, learning_rate=0.001, loss=absolute_error, max_features=log2, n_estimators=256, subsample=0.9;, score=-0.065 total time=   0.5s [repeated 5x across cluster]
# (PoolActor pid=946272, ip=10.19.0.100) [CV 2/5] END criterion=friedman_mse, learning_rate=0.001, loss=absolute_error, max_features=sqrt, n_estimators=64, subsample=0.7;, score=-0.061 total time=   0.1s
# (PoolActor pid=946272, ip=10.19.0.100) [CV 1/5] END criterion=friedman_mse, learning_rate=0.001, loss=huber, max_features=log2, n_estimators=128, subsample=0.85;, score=0.002 total time=   0.9s
# (PoolActor pid=946272, ip=10.19.0.100) [CV 5/5] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=sqrt, n_estimators=128, subsample=0.85;, score=0.248 total time=   0.7s [repeated 7x across cluster]
# (PoolActor pid=946271, ip=10.19.0.100) [CV 1/5] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=64, subsample=0.6;, score=0.125 total time=   0.3s [repeated 47x across cluster]
# (PoolActor pid=946272, ip=10.19.0.100) [CV 3/5] END criterion=friedman_mse, learning_rate=0.001, loss=absolute_error, max_features=log2, n_estimators=16, subsample=0.85;, score=-0.065 total time=   0.0s
# (PoolActor pid=946270, ip=10.19.0.100) [CV 5/5] END criterion=friedman_mse, learning_rate=0.05, loss=squared_error, max_features=sqrt, n_estimators=32, subsample=0.7;, score=0.921 total time=   0.1s
# (PoolActor pid=946276, ip=10.19.0.100) [CV 5/5] END criterion=friedman_mse, learning_rate=0.001, loss=absolute_error, max_features=log2, n_estimators=32, subsample=0.75;, score=-0.064 total time=   0.1s
# (PoolActor pid=946270, ip=10.19.0.100) [CV 1/5] END criterion=friedman_mse, learning_rate=0.05, loss=squared_error, max_features=log2, n_estimators=8, subsample=0.9;, score=0.530 total time=   0.0s
# (PoolActor pid=946270, ip=10.19.0.100) [CV 2/5] END criterion=friedman_mse, learning_rate=0.05, loss=squared_error, max_features=log2, n_estimators=256, subsample=0.75;, score=0.936 total time=   0.7s
# (PoolActor pid=946276, ip=10.19.0.100) [CV 1/5] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=sqrt, n_estimators=16, subsample=0.6;, score=0.026 total time=   0.1s [repeated 6x across cluster]
# (PoolActor pid=946270, ip=10.19.0.100) [CV 3/5] END criterion=friedman_mse, learning_rate=0.05, loss=huber, max_features=sqrt, n_estimators=64, subsample=0.9;, score=0.960 total time=   0.4s
# (PoolActor pid=946270, ip=10.19.0.100) [CV 4/5] END criterion=friedman_mse, learning_rate=0.05, loss=huber, max_features=log2, n_estimators=32, subsample=0.75;, score=0.694 total time=   0.2s
# (PoolActor pid=946270, ip=10.19.0.100) [CV 5/5] END criterion=friedman_mse, learning_rate=0.05, loss=absolute_error, max_features=sqrt, n_estimators=8, subsample=0.9;, score=-0.064 total time=   0.0s
# (PoolActor pid=946270, ip=10.19.0.100) [CV 1/5] END criterion=friedman_mse, learning_rate=0.05, loss=absolute_error, max_features=sqrt, n_estimators=256, subsample=0.8;, score=-0.064 total time=   0.6s
# (PoolActor pid=946270, ip=10.19.0.100) [CV 4/5] END criterion=friedman_mse, learning_rate=0.01, loss=quantile, max_features=log2, n_estimators=64, subsample=0.85;, score=0.816 total time=   0.4s [repeated 12x across cluster]
# (PoolActor pid=946270, ip=10.19.0.100) [CV 1/5] END criterion=friedman_mse, learning_rate=0.001, loss=squared_error, max_features=sqrt, n_estimators=128, subsample=0.7;, score=0.203 total time=   0.3s
# (PoolActor pid=946270, ip=10.19.0.100) [CV 2/5] END criterion=friedman_mse, learning_rate=0.001, loss=squared_error, max_features=log2, n_estimators=32, subsample=0.85;, score=0.058 total time=   0.1s
# (PoolActor pid=946270, ip=10.19.0.100) [CV 3/5] END criterion=friedman_mse, learning_rate=0.001, loss=huber, max_features=sqrt, n_estimators=16, subsample=0.7;, score=-0.056 total time=   0.1s
# (PoolActor pid=946287, ip=10.19.0.100) [CV 5/5] END criterion=friedman_mse, learning_rate=0.001, loss=absolute_error, max_features=log2, n_estimators=256, subsample=0.7;, score=-0.064 total time=   0.6s [repeated 2x across cluster]
# (PoolActor pid=946305, ip=10.19.0.100) [CV 1/5] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=sqrt, n_estimators=8, subsample=0.9;, score=0.009 total time=   0.0s [repeated 4x across cluster]
# (PoolActor pid=946270, ip=10.19.0.100) [CV 4/5] END criterion=friedman_mse, learning_rate=0.001, loss=huber, max_features=sqrt, n_estimators=256, subsample=0.85;, score=0.091 total time=   1.8s
# (PoolActor pid=946315, ip=10.19.0.100) [CV 2/5] END criterion=friedman_mse, learning_rate=0.05, loss=huber, max_features=log2, n_estimators=64, subsample=0.85;, score=0.913 total time=   0.4s
# (PoolActor pid=946315, ip=10.19.0.100) [CV 3/5] END criterion=friedman_mse, learning_rate=0.05, loss=absolute_error, max_features=sqrt, n_estimators=32, subsample=0.7;, score=-0.065 total time=   0.1s
# (PoolActor pid=946320, ip=10.19.0.100) [CV 3/5] END criterion=friedman_mse, learning_rate=0.05, loss=huber, max_features=log2, n_estimators=128, subsample=0.9;, score=0.986 total time=   0.9s
# (PoolActor pid=946325, ip=10.19.0.100) [CV 3/5] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=8, subsample=0.6;, score=0.007 total time=   0.0s [repeated 5x across cluster]
# (PoolActor pid=946320, ip=10.19.0.100) [CV 4/5] END criterion=friedman_mse, learning_rate=0.05, loss=absolute_error, max_features=sqrt, n_estimators=64, subsample=0.75;, score=-0.065 total time=   0.1s
# (PoolActor pid=946315, ip=10.19.0.100) [CV 3/5] END criterion=friedman_mse, learning_rate=0.001, loss=squared_error, max_features=sqrt, n_estimators=8, subsample=0.9;, score=0.014 total time=   0.0s
# (PoolActor pid=946315, ip=10.19.0.100) [CV 4/5] END criterion=friedman_mse, learning_rate=0.001, loss=squared_error, max_features=sqrt, n_estimators=256, subsample=0.75;, score=0.397 total time=   0.7s
# (PoolActor pid=946315, ip=10.19.0.100) [CV 5/5] END criterion=friedman_mse, learning_rate=0.001, loss=squared_error, max_features=log2, n_estimators=64, subsample=0.9;, score=0.106 total time=   0.2s
# (PoolActor pid=946315, ip=10.19.0.100) [CV 1/5] END criterion=friedman_mse, learning_rate=0.001, loss=huber, max_features=sqrt, n_estimators=32, subsample=0.8;, score=-0.048 total time=   0.2s
# (PoolActor pid=946274, ip=10.19.0.100) [CV 3/5] END criterion=friedman_mse, learning_rate=0.05, loss=absolute_error, max_features=log2, n_estimators=128, subsample=0.8;, score=-0.065 total time=   0.3s [repeated 7x across cluster]
# (PoolActor pid=946330, ip=10.19.0.100) [CV 2/5] END criterion=friedman_mse, learning_rate=0.05, loss=quantile, max_features=sqrt, n_estimators=256, subsample=0.75;, score=0.877 total time=   1.4s [repeated 10x across cluster]
# (PoolActor pid=946274, ip=10.19.0.100) [CV 1/5] END criterion=friedman_mse, learning_rate=0.001, loss=huber, max_features=log2, n_estimators=128, subsample=0.9;, score=0.004 total time=   0.8s [repeated 5x across cluster]
# (PoolActor pid=946274, ip=10.19.0.100) [CV 1/5] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=64, subsample=0.8;, score=0.126 total time=   0.3s [repeated 11x across cluster]
# (PoolActor pid=946330, ip=10.19.0.100) [CV 4/5] END criterion=friedman_mse, learning_rate=0.001, loss=absolute_error, max_features=sqrt, n_estimators=16, subsample=0.6;, score=-0.065 total time=   0.0s [repeated 5x across cluster]
# (PoolActor pid=946330, ip=10.19.0.100) [CV 4/5] END criterion=friedman_mse, learning_rate=0.001, loss=squared_error, max_features=sqrt, n_estimators=32, subsample=0.75;, score=0.061 total time=   0.1s [repeated 4x across cluster]
# (PoolActor pid=946330, ip=10.19.0.100) [CV 1/5] END criterion=friedman_mse, learning_rate=0.001, loss=squared_error, max_features=log2, n_estimators=256, subsample=0.8;, score=0.373 total time=   0.7s [repeated 5x across cluster]
# (PoolActor pid=946330, ip=10.19.0.100) [CV 2/5] END criterion=friedman_mse, learning_rate=0.001, loss=huber, max_features=sqrt, n_estimators=128, subsample=0.6;, score=0.008 total time=   0.9s [repeated 3x across cluster]
# (PoolActor pid=946330, ip=10.19.0.100) [CV 1/5] END criterion=friedman_mse, learning_rate=0.001, loss=absolute_error, max_features=log2, n_estimators=128, subsample=0.7;, score=-0.064 total time=   0.3s [repeated 3x across cluster]
# (PoolActor pid=946283, ip=10.19.0.100) [CV 5/5] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=sqrt, n_estimators=32, subsample=0.75;, score=0.061 total time=   0.2s [repeated 7x across cluster]
# (PoolActor pid=946283, ip=10.19.0.100) [CV 1/5] END criterion=friedman_mse, learning_rate=0.001, loss=huber, max_features=log2, n_estimators=32, subsample=0.75;, score=-0.047 total time=   0.2s [repeated 3x across cluster]
# (PoolActor pid=946321, ip=10.19.0.100) [CV 5/5] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=256, subsample=0.75;, score=0.446 total time=   1.4s [repeated 8x across cluster]
# (PoolActor pid=946290, ip=10.19.0.100) [CV 3/5] END criterion=friedman_mse, learning_rate=0.001, loss=absolute_error, max_features=sqrt, n_estimators=32, subsample=0.8;, score=-0.065 total time=   0.1s [repeated 6x across cluster]
# (PoolActor pid=946321, ip=10.19.0.100) [CV 3/5] END criterion=friedman_mse, learning_rate=0.001, loss=huber, max_features=sqrt, n_estimators=64, subsample=0.85;, score=-0.034 total time=   0.5s
# /home/user1/codes/bangaluru_mobility_codes/base/lib/python3.10/site-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# GradientBoosting saved to /home/user1/codes/bangaluru_mobility_codes/submission/future_counts/model_training/results_entire_dataset_each_cam_id/models/Kuvempu_Circle_FIX_1
# Best model score and parameters:
#
# (0.955481135448275, 'GradientBoosting', {'criterion': 'squared_error', 'learning_rate': 0.1, 'loss': 'absolute_error', 'max_features': 'sqrt', 'n_estimators': 128, 'subsample': 0.75})
#
#
#
#
# Training for Mattikere_JN_FIX_2 ...
# SC saved to /home/user1/codes/bangaluru_mobility_codes/submission/future_counts/model_training/results_entire_dataset_each_cam_id/scalers/Mattikere_JN_FIX_2.pkl
# [I] [15:50:43.142823] Unused keyword parameter: copy_X during cuML estimator initialization
# [I] [15:50:43.143107] Unused keyword parameter: copy_X during cuML estimator initialization
# Now evaluating: GradientBoosting
#
#
# Fitting 5 folds for each of 2304 candidates, totalling 11520 fits
# /home/user1/codes/bangaluru_mobility_codes/base/lib/python3.10/site-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# GradientBoosting saved to /home/user1/codes/bangaluru_mobility_codes/submission/future_counts/model_training/results_entire_dataset_each_cam_id/models/Mattikere_JN_FIX_2
# Best model score and parameters:
#
# (0.9745166889694582, 'GradientBoosting', {'criterion': 'squared_error', 'learning_rate': 0.1, 'loss': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 64, 'subsample': 0.7})

# %%
models_report
# Out:
# {'18th_Crs_BsStp_JN_FIX_2': (0.9375828231461629,
#   'GradientBoosting',
#   {'criterion': 'friedman_mse',
#    'learning_rate': 0.1,
#    'loss': 'huber',
#    'max_features': 'sqrt',
#    'n_estimators': 64,
#    'subsample': 0.8}),
#  'Ayyappa_Temple_FIX_1': (0.9539773126983102,
#   'CatBoostingRegressor',
#   {'depth': 4,
#    'iterations': 60,
#    'l2_leaf_reg': 0.01,
#    'learning_rate': 0.11471428571428573}),
#  'Stn_HD_1': (0.9601979753572177,
#   'CatBoostingRegressor',
#   {'depth': 10,
#    'iterations': 160,
#    'l2_leaf_reg': 0.09999999999999999,
#    'learning_rate': 0.029428571428571432}),
#  'SBI_Bnk_JN_FIX_3': (0.9611470844309009,
#   'CatBoostingRegressor',
#   {'depth': 10,
#    'iterations': 160,
#    'l2_leaf_reg': 0.09999999999999999,
#    'learning_rate': 0.029428571428571432}),
#  'Ramaiah_BsStp_JN_FIX_2': (0.9599139671339081,
#   'CatBoostingRegressor',
#   {'depth': 4,
#    'iterations': 210,
#    'l2_leaf_reg': 10.0,
#    'learning_rate': 0.029428571428571432}),
#  'Mattikere_JN_FIX_1': (0.9211983083109135,
#   'GradientBoosting',
#   {'criterion': 'friedman_mse',
#    'learning_rate': 0.1,
#    'loss': 'huber',
#    'max_features': 'log2',
#    'n_estimators': 128,
#    'subsample': 0.6}),
#  'Buddha_Vihara_Temple': (0.9667589130574538,
#   'XGBRegressor',
#   {'gamma': 1.1111111111111112,
#    'learning_rate': 0.11471428571428573,
#    'n_estimators': 58,
#    'reg_alpha': 1.2915496650148826,
#    'reg_lambda': 10.0}),
#  'HP_Ptrl_Bnk_BEL_Rd_FIX_2': (0.940219821195492,
#   'CatBoostingRegressor',
#   {'depth': 4,
#    'iterations': 60,
#    'l2_leaf_reg': 4.641588833612777,
#    'learning_rate': 0.11471428571428573}),
#  'Sundaranagar_Entrance': (0.971410295836016,
#   'GradientBoosting',
#   {'criterion': 'squared_error',
#    'learning_rate': 0.05,
#    'loss': 'squared_error',
#    'max_features': 'sqrt',
#    'n_estimators': 128,
#    'subsample': 0.8}),
#  '80ft_Road': (0.9307498946115438,
#   'GradientBoosting',
#   {'criterion': 'squared_error',
#    'learning_rate': 0.05,
#    'loss': 'huber',
#    'max_features': 'log2',
#    'n_estimators': 128,
#    'subsample': 0.75}),
#  'Devasandra_Sgnl_JN_FIX_1': (0.9575427696621877,
#   'CatBoostingRegressor',
#   {'depth': 6,
#    'iterations': 110,
#    'l2_leaf_reg': 10.0,
#    'learning_rate': 0.057857142857142864}),
#  'Devasandra_Sgnl_JN_FIX_3': (0.9464676834278187,
#   'CatBoostingRegressor',
#   {'depth': 8,
#    'iterations': 110,
#    'l2_leaf_reg': 0.4641588833612777,
#    'learning_rate': 0.0862857142857143}),
#  'Sty_Wll_Ldge_FIX_3': (0.9315495412846608,
#   'GradientBoosting',
#   {'criterion': 'friedman_mse',
#    'learning_rate': 0.05,
#    'loss': 'huber',
#    'max_features': 'log2',
#    'n_estimators': 128,
#    'subsample': 0.75}),
#  'Ramaiah_BsStp_JN_FIX_1': (0.956038625421775,
#   'CatBoostingRegressor',
#   {'depth': 6,
#    'iterations': 210,
#    'l2_leaf_reg': 4.641588833612777,
#    'learning_rate': 0.029428571428571432}),
#  'MS_Ramaiah_JN_FIX_1': (0.9382061819552459,
#   'RandomForest',
#   {'bootstrap': True,
#    'criterion': 'squared_error',
#    'max_features': 'sqrt',
#    'n_estimators': 128}),
#  'MS_Ramaiah_JN_FIX_2': (0.913071675646625,
#   'CatBoostingRegressor',
#   {'depth': 10,
#    'iterations': 110,
#    'l2_leaf_reg': 4.641588833612777,
#    'learning_rate': 0.0862857142857143}),
#  '18th_Crs_Bus_Stop_FIX_2': (0.9638750502979606,
#   'CatBoostingRegressor',
#   {'depth': 6,
#    'iterations': 210,
#    'l2_leaf_reg': 10.0,
#    'learning_rate': 0.029428571428571432}),
#  'SBI_Bnk_JN_FIX_1': (0.9654133069477758,
#   'CatBoostingRegressor',
#   {'depth': 4,
#    'iterations': 210,
#    'l2_leaf_reg': 10.0,
#    'learning_rate': 0.11471428571428573}),
#  'Mattikere_JN_FIX_3': (0.9449369768768134,
#   'CatBoostingRegressor',
#   {'depth': 6,
#    'iterations': 60,
#    'l2_leaf_reg': 10.0,
#    'learning_rate': 0.11471428571428573}),
#  'Mattikere_JN_HD_1': (0.9471187367141327,
#   'Lasso',
#   {'alpha': 0.04229242874389508}),
#  'Kuvempu_Circle_FIX_2': (0.954165213748946,
#   'RandomForest',
#   {'bootstrap': True,
#    'criterion': 'squared_error',
#    'max_features': 'sqrt',
#    'n_estimators': 1024}),
#  'Kuvempu_Circle_FIX_1': (0.955481135448275,
#   'GradientBoosting',
#   {'criterion': 'squared_error',
#    'learning_rate': 0.1,
#    'loss': 'absolute_error',
#    'max_features': 'sqrt',
#    'n_estimators': 128,
#    'subsample': 0.75}),
#  'Mattikere_JN_FIX_2': (0.9745166889694582,
#   'GradientBoosting',
#   {'criterion': 'squared_error',
#    'learning_rate': 0.1,
#    'loss': 'squared_error',
#    'max_features': 'sqrt',
#    'n_estimators': 64,
#    'subsample': 0.7})}
